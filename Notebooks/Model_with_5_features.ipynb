# %%
## Importing libraries

import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
from pycaret.regression import setup, compare_models, create_model, save_model, load_model
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.model_selection import learning_curve, train_test_split
from tqdm import tqdm

# %%
## Importing dataset

batsman_df = pd.read_csv(r"C:\Users\Harsh\Documents\dream11\ipl\Merged Batting CSV\batting.csv")
bowler_df = pd.read_csv(r"C:\Users\Harsh\Documents\dream11\ipl\Merged Bowling CSV\bowling.csv")

# %%
# Converting object data types to categorical variables

# get list of categorical columns
cat_cols = batsman_df.select_dtypes(include=['object']).columns.tolist()
le = LabelEncoder()
for col in cat_cols:
    le.fit(batsman_df[col])
    batsman_df[col] = le.transform(batsman_df[col])

# %%
# Converting object data types to categorical variables

# get list of categorical columns
cat_cols = bowler_df.select_dtypes(include=['object']).columns.tolist()
for col in cat_cols:
    le.fit(bowler_df[col])
    bowler_df[col] = le.transform(bowler_df[col])

# %%
print(batsman_df.isna().sum())
print(bowler_df.isna().sum())
# Out:
# player        0
# runs          0
# balls         0
# 4s            0
# 6s            0
# SR            0
# bowler        0
# fielders      0
# kind          0
# player_out    0
# date          0
# team2         0
# winner        0
# result        0
# venue         0
# team1         0
# MF            0
# 30s           0
# 50s           0
# 100s          0
# 0s            0
# d11           0
# dtype: int64
# player            0
# overs             0
# runs              0
# maidens           0
# wicket            0
# econrate         11
# date              0
# team2             0
# winner            0
# result            0
# venue             0
# team1             0
# MF                0
# 3_wicket_haul     0
# 4_wicket_haul     0
# 5_wicket_haul     0
# d11               0
# dtype: int64

# %%
# Replacing na values with mean 
bowler_df.fillna(bowler_df.mean(), inplace=True)
print(bowler_df.isna().sum())
# Out:
# player           0
# overs            0
# runs             0
# maidens          0
# wicket           0
# econrate         0
# date             0
# team2            0
# winner           0
# result           0
# venue            0
# team1            0
# MF               0
# 3_wicket_haul    0
# 4_wicket_haul    0
# 5_wicket_haul    0
# d11              0
# dtype: int64

# %%
# Checking whether any infinity value
print("For batsman:")
print(np.isinf(batsman_df).any())
print("For bowler:")
print(np.isinf(bowler_df).any())
# Out:
# For batsman:
# player        False
# runs          False
# balls         False
# 4s            False
# 6s            False
# SR            False
# bowler        False
# fielders      False
# kind          False
# player_out    False
# date          False
# team2         False
# winner        False
# result        False
# venue         False
# team1         False
# MF            False
# 30s           False
# 50s           False
# 100s          False
# 0s            False
# d11           False
# dtype: bool
# For bowler:
# player           False
# overs            False
# runs             False
# maidens          False
# wicket           False
# econrate          True
# date             False
# team2            False
# winner           False
# result           False
# venue            False
# team1            False
# MF               False
# 3_wicket_haul    False
# 4_wicket_haul    False
# 5_wicket_haul    False
# d11              False
# dtype: bool

# %%
# replace infinity values in the 'column_name' column with the mean of the column
column_mean = bowler_df['econrate'].replace([np.inf, -np.inf], np.nan).mean()
bowler_df['econrate'].replace([np.inf, -np.inf], column_mean, inplace=True)

# %%
print("Bowler df Columns:")
print(bowler_df.columns)

print("Batsman df Columns:")
print(batsman_df.columns)
# Out:
# Bowler df Columns:
# Index(['player', 'overs', 'runs', 'maidens', 'wicket', 'econrate', 'date',
#        'team2', 'winner', 'result', 'venue', 'team1', 'MF', '3_wicket_haul',
#        '4_wicket_haul', '5_wicket_haul', 'd11'],
#       dtype='object')
# Batsman df Columns:
# Index(['player', 'runs', 'balls', '4s', '6s', 'SR', 'bowler', 'fielders',
#        'kind', 'player_out', 'date', 'team2', 'winner', 'result', 'venue',
#        'team1', 'MF', '30s', '50s', '100s', '0s', 'd11'],
#       dtype='object')

# %%
bowler_df = bowler_df[['player', 'date',
       'team2', 'venue', 'team1', 'MF','d11']]
print("Bowler df Columns:")
print(bowler_df.columns)

batsman_df = batsman_df[['player','date', 'team2','venue',
       'team1', 'MF','d11']]
print("Batsman df Columns:")
print(batsman_df.columns)
# Out:
# Bowler df Columns:
# Index(['player', 'date', 'team2', 'venue', 'team1', 'MF', 'd11'], dtype='object')
# Batsman df Columns:
# Index(['player', 'date', 'team2', 'venue', 'team1', 'MF', 'd11'], dtype='object')

# %% [markdown]
# ### PyCaret: A Low-Code Machine Learning Library in Python
#
# PyCaret is a powerful open-source, low-code machine learning library in Python that streamlines the entire machine learning workflow. With PyCaret, you can automate various aspects of machine learning experiments, saving you time and making you more productive.
#
# #### Key Features and Benefits
#
# - End-to-End Machine Learning: PyCaret provides a seamless end-to-end machine learning experience, handling data preprocessing, feature engineering, model training, hyperparameter tuning, and model evaluation.
#
# - Rapid Experimentation: Replace hundreds of lines of code with just a few words! PyCaret enables you to quickly iterate through different models and configurations, making experiments exponentially fast and efficient.
#
# - Integration with Popular Libraries: PyCaret acts as a convenient Python wrapper around various well-known machine learning libraries and frameworks, including scikit-learn, XGBoost, LightGBM, CatBoost, Optuna, Hyperopt, Ray, and more.
#
# #### How PyCaret Works
#
# 1. **Import the Library**: Start by importing the PyCaret library into your Python environment.
#
# 2. **Load and Preprocess Data**: Load your dataset and perform necessary data preprocessing using PyCaret's simple interface.
#
# 3. **Setup the Experiment**: With just one line of code, set up your machine learning experiment, specifying the target variable and any additional configuration settings.
#
# 4. **Compare Models**: PyCaret lets you quickly compare multiple models with minimal effort, so you can identify the best-performing ones.
#
# 5. **Tune Hyperparameters**: Utilize PyCaret's built-in hyperparameter tuning capabilities to fine-tune your models and improve their performance.
#
# 6. **Evaluate and Analyze Results**: PyCaret provides comprehensive model evaluation metrics and visualizations, making it easy to analyze the results of your experiments.
#
# 7. **Finalize and Deploy Models**: Once you're satisfied with a model, you can finalize it for production and deploy it with ease.
#
# PyCaret is an excellent tool for both beginners and experienced data scientists, empowering them to build high-quality machine learning models efficiently.
#
# Give PyCaret a try and witness the speed and productivity it brings to your machine learning projects!
#
# For more information, visit the [PyCaret GitHub repository](https://github.com/pycaret/pycaret).

# %%
# Set up the PyCaret environment for the batsman dataset
# Make sure to replace 'target' with the name of the target column (the one you want to predict)
batsman_regression_setup = setup(
    data=batsman_df, target='d11',train_size=0.7, verbose=False, preprocess=False
)

# Compare all models and print the results for the batsman dataset
best_batsman_model = compare_models(verbose=True)
compare_models(fold = 5, round = 4, sort = 'R2', turbo = True)
# Out:
# <style type="text/css">
# #T_c5021 th {
#   text-align: left;
# }
# #T_c5021_row0_col0, #T_c5021_row0_col6, #T_c5021_row1_col0, #T_c5021_row1_col1, #T_c5021_row1_col2, #T_c5021_row1_col3, #T_c5021_row1_col4, #T_c5021_row1_col5, #T_c5021_row1_col6, #T_c5021_row2_col0, #T_c5021_row2_col1, #T_c5021_row2_col2, #T_c5021_row2_col3, #T_c5021_row2_col4, #T_c5021_row2_col5, #T_c5021_row2_col6, #T_c5021_row3_col0, #T_c5021_row3_col1, #T_c5021_row3_col2, #T_c5021_row3_col3, #T_c5021_row3_col4, #T_c5021_row3_col5, #T_c5021_row3_col6, #T_c5021_row4_col0, #T_c5021_row4_col1, #T_c5021_row4_col2, #T_c5021_row4_col3, #T_c5021_row4_col4, #T_c5021_row4_col5, #T_c5021_row4_col6, #T_c5021_row5_col0, #T_c5021_row5_col1, #T_c5021_row5_col2, #T_c5021_row5_col3, #T_c5021_row5_col4, #T_c5021_row5_col5, #T_c5021_row5_col6, #T_c5021_row6_col0, #T_c5021_row6_col1, #T_c5021_row6_col2, #T_c5021_row6_col3, #T_c5021_row6_col4, #T_c5021_row6_col5, #T_c5021_row6_col6, #T_c5021_row7_col0, #T_c5021_row7_col1, #T_c5021_row7_col2, #T_c5021_row7_col3, #T_c5021_row7_col4, #T_c5021_row7_col5, #T_c5021_row7_col6, #T_c5021_row8_col0, #T_c5021_row8_col1, #T_c5021_row8_col2, #T_c5021_row8_col3, #T_c5021_row8_col4, #T_c5021_row8_col5, #T_c5021_row8_col6, #T_c5021_row9_col0, #T_c5021_row9_col1, #T_c5021_row9_col2, #T_c5021_row9_col3, #T_c5021_row9_col4, #T_c5021_row9_col5, #T_c5021_row9_col6, #T_c5021_row10_col0, #T_c5021_row10_col1, #T_c5021_row10_col2, #T_c5021_row10_col3, #T_c5021_row10_col4, #T_c5021_row10_col5, #T_c5021_row10_col6, #T_c5021_row11_col0, #T_c5021_row11_col1, #T_c5021_row11_col2, #T_c5021_row11_col3, #T_c5021_row11_col4, #T_c5021_row11_col5, #T_c5021_row11_col6, #T_c5021_row12_col0, #T_c5021_row12_col1, #T_c5021_row12_col2, #T_c5021_row12_col3, #T_c5021_row12_col4, #T_c5021_row12_col5, #T_c5021_row12_col6, #T_c5021_row13_col0, #T_c5021_row13_col1, #T_c5021_row13_col2, #T_c5021_row13_col3, #T_c5021_row13_col4, #T_c5021_row13_col5, #T_c5021_row13_col6, #T_c5021_row14_col0, #T_c5021_row14_col1, #T_c5021_row14_col2, #T_c5021_row14_col3, #T_c5021_row14_col4, #T_c5021_row14_col5, #T_c5021_row14_col6, #T_c5021_row15_col0, #T_c5021_row15_col1, #T_c5021_row15_col2, #T_c5021_row15_col3, #T_c5021_row15_col4, #T_c5021_row15_col5, #T_c5021_row16_col0, #T_c5021_row16_col1, #T_c5021_row16_col2, #T_c5021_row16_col3, #T_c5021_row16_col4, #T_c5021_row16_col5, #T_c5021_row16_col6, #T_c5021_row17_col0, #T_c5021_row17_col1, #T_c5021_row17_col2, #T_c5021_row17_col3, #T_c5021_row17_col4, #T_c5021_row17_col5, #T_c5021_row17_col6, #T_c5021_row18_col0, #T_c5021_row18_col1, #T_c5021_row18_col2, #T_c5021_row18_col3, #T_c5021_row18_col4, #T_c5021_row18_col5, #T_c5021_row18_col6, #T_c5021_row19_col0, #T_c5021_row19_col1, #T_c5021_row19_col2, #T_c5021_row19_col3, #T_c5021_row19_col4, #T_c5021_row19_col5, #T_c5021_row19_col6 {
#   text-align: left;
# }
# #T_c5021_row0_col1, #T_c5021_row0_col2, #T_c5021_row0_col3, #T_c5021_row0_col4, #T_c5021_row0_col5, #T_c5021_row15_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_c5021_row0_col7, #T_c5021_row1_col7, #T_c5021_row2_col7, #T_c5021_row3_col7, #T_c5021_row4_col7, #T_c5021_row5_col7, #T_c5021_row6_col7, #T_c5021_row7_col7, #T_c5021_row8_col7, #T_c5021_row9_col7, #T_c5021_row10_col7, #T_c5021_row11_col7, #T_c5021_row12_col7, #T_c5021_row14_col7, #T_c5021_row15_col7, #T_c5021_row16_col7, #T_c5021_row17_col7, #T_c5021_row18_col7, #T_c5021_row19_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_c5021_row13_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_c5021">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c5021_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_c5021_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_c5021_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_c5021_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_c5021_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_c5021_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_c5021_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_c5021_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c5021_level0_row0" class="row_heading level0 row0" >rf</th>
#       <td id="T_c5021_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_c5021_row0_col1" class="data row0 col1" >19.9549</td>
#       <td id="T_c5021_row0_col2" class="data row0 col2" >734.9322</td>
#       <td id="T_c5021_row0_col3" class="data row0 col3" >27.0999</td>
#       <td id="T_c5021_row0_col4" class="data row0 col4" >0.1602</td>
#       <td id="T_c5021_row0_col5" class="data row0 col5" >1.2401</td>
#       <td id="T_c5021_row0_col6" class="data row0 col6" >3.7344</td>
#       <td id="T_c5021_row0_col7" class="data row0 col7" >2.4110</td>
#     </tr>
#     <tr>
#       <th id="T_c5021_level0_row1" class="row_heading level0 row1" >catboost</th>
#       <td id="T_c5021_row1_col0" class="data row1 col0" >CatBoost Regressor</td>
#       <td id="T_c5021_row1_col1" class="data row1 col1" >21.2548</td>
#       <td id="T_c5021_row1_col2" class="data row1 col2" >789.6962</td>
#       <td id="T_c5021_row1_col3" class="data row1 col3" >28.0929</td>
#       <td id="T_c5021_row1_col4" class="data row1 col4" >0.0983</td>
#       <td id="T_c5021_row1_col5" class="data row1 col5" >1.2807</td>
#       <td id="T_c5021_row1_col6" class="data row1 col6" >3.9447</td>
#       <td id="T_c5021_row1_col7" class="data row1 col7" >2.4020</td>
#     </tr>
#     <tr>
#       <th id="T_c5021_level0_row2" class="row_heading level0 row2" >xgboost</th>
#       <td id="T_c5021_row2_col0" class="data row2 col0" >Extreme Gradient Boosting</td>
#       <td id="T_c5021_row2_col1" class="data row2 col1" >20.9919</td>
#       <td id="T_c5021_row2_col2" class="data row2 col2" >790.7274</td>
#       <td id="T_c5021_row2_col3" class="data row2 col3" >28.1150</td>
#       <td id="T_c5021_row2_col4" class="data row2 col4" >0.0965</td>
#       <td id="T_c5021_row2_col5" class="data row2 col5" >1.2615</td>
#       <td id="T_c5021_row2_col6" class="data row2 col6" >3.7574</td>
#       <td id="T_c5021_row2_col7" class="data row2 col7" >0.8970</td>
#     </tr>
#     <tr>
#       <th id="T_c5021_level0_row3" class="row_heading level0 row3" >lightgbm</th>
#       <td id="T_c5021_row3_col0" class="data row3 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_c5021_row3_col1" class="data row3 col1" >21.4279</td>
#       <td id="T_c5021_row3_col2" class="data row3 col2" >798.8314</td>
#       <td id="T_c5021_row3_col3" class="data row3 col3" >28.2534</td>
#       <td id="T_c5021_row3_col4" class="data row3 col4" >0.0881</td>
#       <td id="T_c5021_row3_col5" class="data row3 col5" >1.2912</td>
#       <td id="T_c5021_row3_col6" class="data row3 col6" >4.0236</td>
#       <td id="T_c5021_row3_col7" class="data row3 col7" >0.9750</td>
#     </tr>
#     <tr>
#       <th id="T_c5021_level0_row4" class="row_heading level0 row4" >gbr</th>
#       <td id="T_c5021_row4_col0" class="data row4 col0" >Gradient Boosting Regressor</td>
#       <td id="T_c5021_row4_col1" class="data row4 col1" >21.9200</td>
#       <td id="T_c5021_row4_col2" class="data row4 col2" >827.8775</td>
#       <td id="T_c5021_row4_col3" class="data row4 col3" >28.7618</td>
#       <td id="T_c5021_row4_col4" class="data row4 col4" >0.0551</td>
#       <td id="T_c5021_row4_col5" class="data row4 col5" >1.3159</td>
#       <td id="T_c5021_row4_col6" class="data row4 col6" >4.1719</td>
#       <td id="T_c5021_row4_col7" class="data row4 col7" >1.0080</td>
#     </tr>
#     <tr>
#       <th id="T_c5021_level0_row5" class="row_heading level0 row5" >et</th>
#       <td id="T_c5021_row5_col0" class="data row5 col0" >Extra Trees Regressor</td>
#       <td id="T_c5021_row5_col1" class="data row5 col1" >20.9606</td>
#       <td id="T_c5021_row5_col2" class="data row5 col2" >840.3014</td>
#       <td id="T_c5021_r
# <style type="text/css">
# #T_d3bc8 th {
#   text-align: left;
# }
# #T_d3bc8_row0_col0, #T_d3bc8_row0_col6, #T_d3bc8_row1_col0, #T_d3bc8_row1_col1, #T_d3bc8_row1_col2, #T_d3bc8_row1_col3, #T_d3bc8_row1_col4, #T_d3bc8_row1_col5, #T_d3bc8_row1_col6, #T_d3bc8_row2_col0, #T_d3bc8_row2_col1, #T_d3bc8_row2_col2, #T_d3bc8_row2_col3, #T_d3bc8_row2_col4, #T_d3bc8_row2_col5, #T_d3bc8_row2_col6, #T_d3bc8_row3_col0, #T_d3bc8_row3_col1, #T_d3bc8_row3_col2, #T_d3bc8_row3_col3, #T_d3bc8_row3_col4, #T_d3bc8_row3_col5, #T_d3bc8_row3_col6, #T_d3bc8_row4_col0, #T_d3bc8_row4_col1, #T_d3bc8_row4_col2, #T_d3bc8_row4_col3, #T_d3bc8_row4_col4, #T_d3bc8_row4_col5, #T_d3bc8_row4_col6, #T_d3bc8_row5_col0, #T_d3bc8_row5_col1, #T_d3bc8_row5_col2, #T_d3bc8_row5_col3, #T_d3bc8_row5_col4, #T_d3bc8_row5_col5, #T_d3bc8_row5_col6, #T_d3bc8_row6_col0, #T_d3bc8_row6_col1, #T_d3bc8_row6_col2, #T_d3bc8_row6_col3, #T_d3bc8_row6_col4, #T_d3bc8_row6_col5, #T_d3bc8_row6_col6, #T_d3bc8_row7_col0, #T_d3bc8_row7_col1, #T_d3bc8_row7_col2, #T_d3bc8_row7_col3, #T_d3bc8_row7_col4, #T_d3bc8_row7_col5, #T_d3bc8_row7_col6, #T_d3bc8_row8_col0, #T_d3bc8_row8_col1, #T_d3bc8_row8_col2, #T_d3bc8_row8_col3, #T_d3bc8_row8_col4, #T_d3bc8_row8_col5, #T_d3bc8_row8_col6, #T_d3bc8_row9_col0, #T_d3bc8_row9_col1, #T_d3bc8_row9_col2, #T_d3bc8_row9_col3, #T_d3b
row5_col0" class="data row5 col0" >Extra Trees Regressor</td>
#       <td id="T_d3bc8_row5_col1" class="data row5 col1" >21.2559</td>
#       <td id="T_d3bc8_row5_col2" class="data row5 col2" >853.9439</td>
#       <td id="T_d3bc8_r
# RandomForestRegressor(n_jobs=-1, random_state=7776)

# %%
# Create the Random Forest Regressor model for the batsman dataset using the top-performing model's hyperparameters
batsman_rf_model = create_model('rf', fold=5)

# Save the trained Random Forest Regressor model model for the batsman dataset to a file
save_model(batsman_rf_model, 'batsman_Random_Forest_Regressor_model')
# Out:
# <style type="text/css">
# #T_4552c_row5_col0, #T_4552c_row5_col1, #T_4552c_row5_col2, #T_4552c_row5_col3, #T_4552c_row5_col4, #T_4552c_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_4552c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4552c_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_4552c_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_4552c_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_4552c_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_4552c_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_4552c_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4552c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4552c_row0_col0" class="data row0 col0" >22.3211</td>
#       <td id="T_4552c_row0_col1" class="data row0 col1" >854.8935</td>
#       <td id="T_4552c_row0_col2" class="data row0 col2" >29.2386</td>
#       <td id="T_4552c_row0_col3" class="data row0 col3" >0.0498</td>
#       <td id="T_4552c_row0_col4" class="data row0 col4" >1.3469</td>
#       <td id="T_4552c_row0_col5" class="data row0 col5" >4.2705</td>
#     </tr>
#     <tr>
#       <th id="T_4552c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4552c_row1_col0" class="data row1 col0" >22.0206</td>
#       <td id="T_4552c_row1_col1" class="data row1 col1" >818.6301</td>
#       <td id="T_4552c_row1_col2" class="data row1 col2" >28.6117</td>
#       <td id="T_4552c_row1_col3" class="data row1 col3" >0.0482</td>
#       <td id="T_4552c_row1_col4" class="data row1 col4" >1.3398</td>
#       <td id="T_4552c_row1_col5" class="data row1 col5" >4.2616</td>
#     </tr>
#     <tr>
#       <th id="T_4552c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4552c_row2_col0" class="data row2 col0" >22.1176</td>
#       <td id="T_4552c_row2_col1" class="data row2 col1" >844.3365</td>
#       <td id="T_4552c_row2_col2" class="data row2 col2" >29.0575</td>
#       <td id="T_4552c_row2_col3" class="data row2 col3" >0.0578</td>
#       <td id="T_4552c_row2_col4" class="data row2 col4" >1.3118</td>
#       <td id="T_4552c_row2_col5" class="data row2 col5" >4.3255</td>
#     </tr>
#     <tr>
#       <th id="T_4552c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4552c_row3_col0" class="data row3 col0" >21.9769</td>
#       <td id="T_4552c_row3_col1" class="data row3 col1" >859.3222</td>
#       <td id="T_4552c_row3_col2" class="data row3 col2" >29.3142</td>
#       <td id="T_4552c_row3_col3" class="data row3 col3" >0.0514</td>
#       <td id="T_4552c_row3_col4" class="data row3 col4" >1.2993</td>
#       <td id="T_4552c_row3_col5" class="data row3 col5" >4.1408</td>
#     </tr>
#     <tr>
#       <th id="T_4552c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4552c_row4_col0" class="data row4 col0" >21.3906</td>
#       <td id="T_4552c_row4_col1" class="data row4 col1" >779.6506</td>
#       <td id="T_4552c_row4_col2" class="data row4 col2" >27.9222</td>
#       <td id="T_4552c_row4_col3" class="data row4 col3" >0.0506</td>
#       <td id="T_4552c_row4_col4" class="data row4 col4" >1.2907</td>
#       <td id="T_4552c_row4_col5" class="data row4 col5" >3.9072</td>
#     </tr>
#     <tr>
#       <th id="T_4552c_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_4552c_row5_col0" class="data row5 col0" >21.9654</td>
#       <td id="T_4552c_row5_col1" class="data row5 col1" >831.3666</td>
#       <td id="T_4552c_row5_col2" class="data row5 col2" >28.8288</td>
#       <td id="T_4552c_row5_col3" class="data row5 col3" >0.0516</td>
#       <td id="T_4552c_row5_col4" class="data row5 col4" >1.3177</td>
#       <td id="T_4552c_row5_col5" class="data row5 col5" >4.1811</td>
#     </tr>
#     <tr>
#       <th id="T_4552c_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_4552c_row6_col0" class="data row6 col0" >0.3109</td>
#       <td id="T_4552c_row6_col1" class="data row6 col1" >29.4619</td>
#       <td id="T_4552c_row6_col2" class="data row6 col2" >0.5147</td>
#       <td id="T_4552c_row6_col3" class="data row6 col3" >0.0033</td>
#       <td id="T_4552c_row6_col4" class="data row6 col4" >0.0221</td>
#       <td id="T_4552c_row6_col5" class="data row6 col5" >0.1496</td>
#     </tr>
#   </tbody>
# </table>
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=FastMemory(location=C:\Users\harsh\AppData\Local\Temp\joblib),
#           steps=[('placeholder', None),
#                  ('trained_model',
#                   GradientBoostingRegressor(random_state=7776))]),
#  'batsman_Gradient_Boosting_Regressor_model.pkl')

# %%
# Set up the PyCaret environment for the bowler dataset
# Make sure to replace 'target' with the name of the target column (the one you want to predict)
bowler_regression_setup = setup(bowler_df, target='d11', train_size=0.7, 
                                verbose=False, preprocess=False)

# Compare all models and print the results for the bowler dataset
best_bowler_model = compare_models(verbose = True)
compare_models(fold = 5,round = 4,sort = 'R2',turbo = True)
# Out:
# <style type="text/css">
# #T_593de th {
#   text-align: left;
# }
# #T_593de_row0_col0, #T_593de_row0_col1, #T_593de_row1_col0, #T_593de_row1_col1, #T_593de_row1_col2, #T_593de_row1_col3, #T_593de_row1_col4, #T_593de_row1_col5, #T_593de_row1_col6, #T_593de_row2_col0, #T_593de_row2_col1, #T_593de_row2_col2, #T_593de_row2_col3, #T_593de_row2_col4, #T_593de_row2_col5, #T_593de_row2_col6, #T_593de_row3_col0, #T_593de_row3_col1, #T_593de_row3_col2, #T_593de_row3_col3, #T_593de_row3_col4, #T_593de_row3_col5, #T_593de_row3_col6, #T_593de_row4_col0, #T_593de_row4_col1, #T_593de_row4_col2, #T_593de_row4_col3, #T_593de_row4_col4, #T_593de_row4_col5, #T_593de_row4_col6, #T_593de_row5_col0, #T_593de_row5_col1, #T_593de_row5_col2, #T_593de_row5_col3, #T_593de_row5_col4, #T_593de_row5_col5, #T_593de_row5_col6, #T_593de_row6_col0, #T_593de_row6_col1, #T_593de_row6_col2, #T_593de_row6_col3, #T_593de_row6_col4, #T_593de_row6_col5, #T_593de_row6_col6, #T_593de_row7_col0, #T_593de_row7_col1, #T_593de_row7_col2, #T_593de_row7_col3, #T_593de_row7_col4, #T_593de_row7_col5, #T_593de_row7_col6, #T_593de_row8_col0, #T_593de_row8_col1, #T_593de_row8_col2, #T_593de_row8_col3, #T_593de_row8_col4, #T_593de_row8_col5, #T_593de_row8_col6, #T_593de_row9_col0, #T_593de_row9_col1, #T_593de_row9_col2, #T_593de_row9_col3, #T_593de_row9_col4, #T_593de_row9_col5, #T_593de_row9_col6, #T_593de_row10_col0, #T_593de_row10_col1, #T_593de_row10_col2, #T_593de_row10_col3, #T_593de_row10_col4, #T_593de_row10_col5, #T_593de_row10_col6, #T_593de_row11_col0, #T_593de_row11_col1, #T_593de_row11_col2, #T_593de_row11_col3, #T_593de_row11_col4, #T_593de_row11_col5, #T_593de_row11_col6, #T_593de_row12_col0, #T_593de_row12_col1, #T_593de_row12_col2, #T_593de_row12_col3, #T_593de_row12_col4, #T_593de_row12_col5, #T_593de_row12_col6, #T_593de_row13_col0, #T_593de_row13_col1, #T_593de_row13_col2, #T_593de_row13_col3, #T_593de_row13_col4, #T_593de_row13_col5, #T_593de_row13_col6, #T_593de_row14_col0, #T_593de_row14_col1, #T_593de_row14_col2, #T_593de_row14_col3, #T_593de_row14_col4, #T_593de_row14_col5, #T_593de_row14_col6, #T_593de_row15_col0, #T_593de_row15_col1, #T_593de_row15_col2, #T_593de_row15_col3, #T_593de_row15_col4, #T_593de_row15_col5, #T_593de_row15_col6, #T_593de_row16_col0, #T_593de_row16_col1, #T_593de_row16_col2, #T_593de_row16_col3, #T_593de_row16_col4, #T_593de_row16_col5, #T_593de_row16_col6, #T_593de_row17_col0, #T_593de_row17_col1, #T_593de_row17_col2, #T_593de_row17_col3, #T_593de_row17_col4, #T_593de_row17_col5, #T_593de_row17_col6, #T_593de_row18_col0, #T_593de_row18_col2, #T_593de_row18_col3, #T_593de_row18_col4, #T_593de_row18_col5, #T_593de_row18_col6, #T_593de_row19_col0, #T_593de_row19_col1, #T_593de_row19_col2, #T_593de_row19_col3, #T_593de_row19_col4, #T_593de_row19_col5, #T_593de_row19_col6 {
#   text-align: left;
# }
# #T_593de_row0_col2, #T_593de_row0_col3, #T_593de_row0_col4, #T_593de_row0_col5, #T_593de_row0_col6, #T_593de_row18_col1 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_593de_row0_col7, #T_593de_row1_col7, #T_593de_row2_col7, #T_593de_row3_col7, #T_593de_row4_col7, #T_593de_row5_col7, #T_593de_row6_col7, #T_593de_row7_col7, #T_593de_row8_col7, #T_593de_row9_col7, #T_593de_row11_col7, #T_593de_row12_col7, #T_593de_row13_col7, #T_593de_row14_col7, #T_593de_row15_col7, #T_593de_row16_col7, #T_593de_row17_col7, #T_593de_row18_col7, #T_593de_row19_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_593de_row10_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_593de">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_593de_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_593de_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_593de_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_593de_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_593de_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_593de_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_593de_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_593de_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_593de_level0_row0" class="row_heading level0 row0" >rf</th>
#       <td id="T_593de_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_593de_row0_col1" class="data row0 col1" >11.2709</td>
#       <td id="T_593de_row0_col2" class="data row0 col2" >164.3806</td>
#       <td id="T_593de_row0_col3" class="data row0 col3" >12.8205</td>
#       <td id="T_593de_row0_col4" class="data row0 col4" >0.0522</td>
#       <td id="T_593de_row0_col5" class="data row0 col5" >1.7371</td>
#       <td id="T_593de_row0_col6" class="data row0 col6" >0.3548</td>
#       <td id="T_593de_row0_col7" class="data row0 col7" >1.3830</td>
#     </tr>
#     <tr>
#       <th id="T_593de_level0_row1" class="row_heading level0 row1" >catboost</th>
#       <td id="T_593de_row1_col0" class="data row1 col0" >CatBoost Regressor</td>
#       <td id="T_593de_row1_col1" class="data row1 col1" >11.9225</td>
#       <td id="T_593de_row1_col2" class="data row1 col2" >167.5667</td>
#       <td id="T_593de_row1_col3" class="data row1 col3" >12.9439</td>
#       <td id="T_593de_row1_col4" class="data row1 col4" >0.0339</td>
#       <td id="T_593de_row1_col5" class="data row1 col5" >1.7797</td>
#       <td id="T_593de_row1_col6" class="data row1 col6" >0.3719</td>
#       <td id="T_593de_row1_col7" class="data row1 col7" >1.7020</td>
#     </tr>
#     <tr>
#       <th id="T_593de_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_593de_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_593de_row2_col1" class="data row2 col1" >12.0358</td>
#       <td id="T_593de_row2_col2" class="data row2 col2" >167.7101</td>
#       <td id="T_593de_row2_col3" class="data row2 col3" >12.9497</td>
#       <td id="T_593de_row2_col4" class="data row2 col4" >0.0330</td>
#       <td id="T_593de_row2_col5" class="data row2 col5" >1.7862</td>
#       <td id="T_593de_row2_col6" class="data row2 col6" >0.3746</td>
#       <td id="T_593de_row2_col7" class="data row2 col7" >0.8500</td>
#     </tr>
#     <tr>
#       <th id="T_593de_level0_row3" class="row_heading level0 row3" >gbr</th>
#       <td id="T_593de_row3_col0" class="data row3 col0" >Gradient Boosting Regressor</td>
#       <td id="T_593de_row3_col1" class="data row3 col1" >12.3504</td>
#       <td id="T_593de_row3_col2" class="data row3 col2" >169.5679</td>
#       <td id="T_593de_row3_col3" class="data row3 col3" >13.0215</td>
#       <td id="T_593de_row3_col4" class="data row3 col4" >0.0223</td>
#       <td id="T_593de_row3_col5" class="data row3 col5" >1.8041</td>
#       <td id="T_593de_row3_col6" class="data row3 col6" >0.3837</td>
#       <td id="T_593de_row3_col7" class="data row3 col7" >1.0250</td>
#     </tr>
#     <tr>
#       <th id="T_593de_level0_row4" class="row_heading level0 row4" >xgboost</th>
#       <td id="T_593de_row4_col0" class="data row4 col0" >Extreme Gradient Boosting</td>
#       <td id="T_593de_row4_col1" class="data row4 col1" >11.4657</td>
#       <td id="T_593de_row4_col2" class="data row4 col2" >170.8738</td>
#       <td id="T_593de_row4_col3" class="data row4 col3" >13.0710</td>
#       <td id="T_593de_row4_col4" class="data row4 col4" >0.0147</td>
#       <td id="T_593de_row4_col5" class="data row4 col5" >1.7503</td>
#       <td id="T_593de_row4_col6" class="data row4 col6" >0.3626</td>
#       <td id="T_593de_row4_col7" class="data row4 col7" >0.7830</td>
#     </tr>
#     <tr>
#       <th id="T_593de_level0_row5" class="row_heading level0 row5" >ada</th>
#       <td id="T_593de_row5_col0" class="data row5 col0" >AdaBoost Regressor</td>
#       <td id="T_593de_row5_col1" class="data row5 col1" >12.6500</td>
#       <td id="T_593de_row5_col2" class="data row5 col2" >173.3926</td>
#       <td id="T_593de_row
# <style type="text/css">
# #T_8d438 th {
#   text-align: left;
# }
# #T_8d438_row0_col0, #T_8d438_row1_col0, #T_8d438_row1_col1, #T_8d438_row1_col2, #T_8d438_row1_col3, #T_8d438_row1_col4, #T_8d438_row1_col5, #T_8d438_row1_col6, #T_8d438_row2_col0, #T_8d438_row2_col1, #T_8d438_row2_col2, #T_8d438_row2_col3, #T_8d438_row2_col4, #T_8d438_row2_col5, #T_8d438_row2_col6, #T_8d438_row3_col0, #T_8d438_row3_col1, #T_8d438_row3_col2, #T_8d438_row3_col3, #T_8d438_row3_col4, #T_8d438_row3_col5, #T_8d438_row3_col6, #T_8d438_row4_col0, #T_8d438_row4_col1, #T_8d438_row4_col2, #T_8d438_row4_col3, #T_8d438_row4_col4, #T_8d438_row4_col5, #T_8d438_row4_col6, #T_8d438_row5_col0, #T_8d438_row5_col1, #T_8d438_row5_col2, #T_8d438_row5_col3, #T_8d438_row5_col4, #T_8d438_row5_col5, #
level0_row5" class="row_heading level0 row5" >dummy</th>
#       <td id="T_8d438_row5_col0" class="data row5 col0" >Dummy Regressor</td>
#       <td id="T_8d438_row5_col1" class="data row5 col1" >12.6144</td>
#       <td id="T_8d438_row5_col2" class="data row5 col2" >173.6637</td>
#       <td id="T_8d438_row5_col3" clas
# RandomForestRegressor(n_jobs=-1, random_state=2763)

# %%
# Create the Random Forest Regressor model for the bowler dataset using the top-performing model's hyperparameters
bowler_rf_model = create_model('rf', fold=5)

# Save the trained Random Forest Regressor model for the bowler dataset to a file
save_model(bowler_rf_model, 'bowler_Random_Forest_Regressor_model')
# Out:
# <style type="text/css">
# #T_bef07_row5_col0, #T_bef07_row5_col1, #T_bef07_row5_col2, #T_bef07_row5_col3, #T_bef07_row5_col4, #T_bef07_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_bef07">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bef07_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_bef07_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_bef07_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_bef07_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_bef07_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_bef07_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bef07_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bef07_row0_col0" class="data row0 col0" >12.4101</td>
#       <td id="T_bef07_row0_col1" class="data row0 col1" >172.0637</td>
#       <td id="T_bef07_row0_col2" class="data row0 col2" >13.1173</td>
#       <td id="T_bef07_row0_col3" class="data row0 col3" >0.0231</td>
#       <td id="T_bef07_row0_col4" class="data row0 col4" >1.8462</td>
#       <td id="T_bef07_row0_col5" class="data row0 col5" >0.3764</td>
#     </tr>
#     <tr>
#       <th id="T_bef07_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_bef07_row1_col0" class="data row1 col0" >12.3034</td>
#       <td id="T_bef07_row1_col1" class="data row1 col1" >168.9833</td>
#       <td id="T_bef07_row1_col2" class="data row1 col2" >12.9994</td>
#       <td id="T_bef07_row1_col3" class="data row1 col3" >0.0150</td>
#       <td id="T_bef07_row1_col4" class="data row1 col4" >1.8070</td>
#       <td id="T_bef07_row1_col5" class="data row1 col5" >0.3791</td>
#     </tr>
#     <tr>
#       <th id="T_bef07_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_bef07_row2_col0" class="data row2 col0" >12.3897</td>
#       <td id="T_bef07_row2_col1" class="data row2 col1" >170.5033</td>
#       <td id="T_bef07_row2_col2" class="data row2 col2" >13.0577</td>
#       <td id="T_bef07_row2_col3" class="data row2 col3" >0.0190</td>
#       <td id="T_bef07_row2_col4" class="data row2 col4" >1.7846</td>
#       <td id="T_bef07_row2_col5" class="data row2 col5" >0.3897</td>
#     </tr>
#     <tr>
#       <th id="T_bef07_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_bef07_row3_col0" class="data row3 col0" >12.4108</td>
#       <td id="T_bef07_row3_col1" class="data row3 col1" >170.5834</td>
#       <td id="T_bef07_row3_col2" class="data row3 col2" >13.0608</td>
#       <td id="T_bef07_row3_col3" class="data row3 col3" >0.0254</td>
#       <td id="T_bef07_row3_col4" class="data row3 col4" >1.8033</td>
#       <td id="T_bef07_row3_col5" class="data row3 col5" >0.3891</td>
#     </tr>
#     <tr>
#       <th id="T_bef07_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_bef07_row4_col0" class="data row4 col0" >12.2808</td>
#       <td id="T_bef07_row4_col1" class="data row4 col1" >167.3344</td>
#       <td id="T_bef07_row4_col2" class="data row4 col2" >12.9358</td>
#       <td id="T_bef07_row4_col3" class="data row4 col3" >0.0231</td>
#       <td id="T_bef07_row4_col4" class="data row4 col4" >1.7845</td>
#       <td id="T_bef07_row4_col5" class="data row4 col5" >0.3845</td>
#     </tr>
#     <tr>
#       <th id="T_bef07_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_bef07_row5_col0" class="data row5 col0" >12.3590</td>
#       <td id="T_bef07_row5_col1" class="data row5 col1" >169.8936</td>
#       <td id="T_bef07_row5_col2" class="data row5 col2" >13.0342</td>
#       <td id="T_bef07_row5_col3" class="data row5 col3" >0.0211</td>
#       <td id="T_bef07_row5_col4" class="data row5 col4" >1.8051</td>
#       <td id="T_bef07_row5_col5" class="data row5 col5" >0.3837</td>
#     </tr>
#     <tr>
#       <th id="T_bef07_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_bef07_row6_col0" class="data row6 col0" >0.0556</td>
#       <td id="T_bef07_row6_col1" class="data row6 col1" >1.6084</td>
#       <td id="T_bef07_row6_col2" class="data row6 col2" >0.0617</td>
#       <td id="T_bef07_row6_col3" class="data row6 col3" >0.0037</td>
#       <td id="T_bef07_row6_col4" class="data row6 col4" >0.0226</td>
#       <td id="T_bef07_row6_col5" class="data row6 col5" >0.0053</td>
#     </tr>
#   </tbody>
# </table>
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=FastMemory(location=C:\Users\harsh\AppData\Local\Temp\joblib),
#           steps=[('placeholder', None),
#                  ('trained_model',
#                   GradientBoostingRegressor(random_state=2763))]),
#  'bowler_Gradient_Boosting_Regressor_model.pkl')

# %%
# Split the datasets into train and test sets 
train_batsman_df, test_batsman_df = train_test_split(
    batsman_df, test_size=0.2, random_state=42
)
train_bowler_df, test_bowler_df = train_test_split(
    bowler_df, test_size=0.2, random_state=42
)

# %%
X_train_batsman = train_batsman_df.iloc[:,:-1]
y_train_batsman = train_batsman_df.iloc[:,-1:]

X_test_batsman = test_batsman_df.iloc[:,:-1]
y_test_batsman = test_batsman_df.iloc[:,-1:]

X_train_bowler = train_bowler_df.iloc[:,:-1]
y_train_bowler = train_bowler_df.iloc[:,-1:]

X_test_bowler = test_bowler_df.iloc[:,:-1]
y_test_bowler = test_bowler_df.iloc[:,-1:]

# %%
# Print X_train_batsman column names
print("X_train Batsman Columns:")
print(X_train_batsman.columns)

# Print y_train_batsman column names
print("y_train Batsman Columns:")
print(y_train_batsman.columns)

# Print X_train_bowler column names
print("X_train Bowler Columns:")
print(X_train_bowler.columns)

# Print y_train_bowler column names
print("y_train Bowler Columns:")
print(y_train_bowler.columns)
# Out:
# X_train Batsman Columns:
# Index(['player', 'date', 'team2', 'venue', 'team1', 'MF'], dtype='object')
# y_train Batsman Columns:
# Index(['d11'], dtype='object')
# X_train Bowler Columns:
# Index(['player', 'date', 'team2', 'venue', 'team1', 'MF'], dtype='object')
# y_train Bowler Columns:
# Index(['d11'], dtype='object')

# %%
## Predicting for batsman
batsman_rf_model.fit(X_train_batsman, y_train_batsman)
pred = batsman_rf_model.predict(X_test_batsman)
r2 = r2_score(pred,y_test_batsman)
print('The r2 using gbr is:',r2)
# Out:
# The r2 using gbr is: -29.761309773177064

# %%
## Predicting for bowler
bowler_rf_model.fit(X_train_bowler, y_train_bowler)
pred = bowler_rf_model.predict(X_test_bowler)
r2 = r2_score(pred,y_test_bowler)
print('The r2 using gbr is:',r2)
# Out:
# The r2 using gbr is: -55.84587437927597
