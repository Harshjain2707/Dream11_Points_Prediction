# %%
## Importing libraries

import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
from pycaret.regression import setup, compare_models, create_model, save_model, load_model
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.model_selection import learning_curve, train_test_split

# %%
# Importing dataset

batsman_df = pd.read_csv(r"C:\Users\harsh\Documents\dream11\ipl\Merged Batting CSV\batting.csv")
bowler_df = pd.read_csv(r"C:\Users\Harsh\Documents\dream11\ipl\Merged Bowling CSV\bowling.csv")

# %%
# print(batsman_df.dtypes)
# print(bowler_df.dtypes)

# %%
# get list of categorical columns
cat_cols = batsman_df.select_dtypes(include=['object']).columns.tolist()

# Converting object data types to categorical variables
le = LabelEncoder()
for col in cat_cols:
    le.fit(batsman_df[col])
    batsman_df[col] = le.transform(batsman_df[col])

# %%
cat_cols = bowler_df.select_dtypes(include=['object']).columns.tolist()
cat_cols
for col in cat_cols:
    le.fit(bowler_df[col])
    bowler_df[col] = le.transform(bowler_df[col])

# %%
# Checking whether any na values and replacing it with mean 
# print(bowler_df.isna().sum())
bowler_df.fillna(bowler_df.mean(), inplace=True)
# print(bowler_df.isna().sum())
# Checking whether any infinity value
# print(np.isinf(bowler_df).any())

# %%
# replace infinity values in the 'column_name' column with the mean of the column
column_mean = bowler_df['econrate'].replace([np.inf, -np.inf], np.nan).mean()
bowler_df['econrate'].replace([np.inf, -np.inf], column_mean, inplace=True)
print(np.isinf(bowler_df).any())
# Out:
# player           False
# overs            False
# runs             False
# maidens          False
# wicket           False
# econrate         False
# date             False
# team2            False
# winner           False
# result           False
# venue            False
# team1            False
# MF               False
# 3_wicket_haul    False
# 4_wicket_haul    False
# 5_wicket_haul    False
# d11              False
# dtype: bool

# %% [markdown]
# ### PyCaret: A Low-Code Machine Learning Library in Python
#
# PyCaret is a powerful open-source, low-code machine learning library in Python that streamlines the entire machine learning workflow. With PyCaret, you can automate various aspects of machine learning experiments, saving you time and making you more productive.
#
# #### Key Features and Benefits
#
# - End-to-End Machine Learning: PyCaret provides a seamless end-to-end machine learning experience, handling data preprocessing, feature engineering, model training, hyperparameter tuning, and model evaluation.
#
# - Rapid Experimentation: Replace hundreds of lines of code with just a few words! PyCaret enables you to quickly iterate through different models and configurations, making experiments exponentially fast and efficient.
#
# - Integration with Popular Libraries: PyCaret acts as a convenient Python wrapper around various well-known machine learning libraries and frameworks, including scikit-learn, XGBoost, LightGBM, CatBoost, Optuna, Hyperopt, Ray, and more.
#
# #### How PyCaret Works
#
# 1. **Import the Library**: Start by importing the PyCaret library into your Python environment.
#
# 2. **Load and Preprocess Data**: Load your dataset and perform necessary data preprocessing using PyCaret's simple interface.
#
# 3. **Setup the Experiment**: With just one line of code, set up your machine learning experiment, specifying the target variable and any additional configuration settings.
#
# 4. **Compare Models**: PyCaret lets you quickly compare multiple models with minimal effort, so you can identify the best-performing ones.
#
# 5. **Tune Hyperparameters**: Utilize PyCaret's built-in hyperparameter tuning capabilities to fine-tune your models and improve their performance.
#
# 6. **Evaluate and Analyze Results**: PyCaret provides comprehensive model evaluation metrics and visualizations, making it easy to analyze the results of your experiments.
#
# 7. **Finalize and Deploy Models**: Once you're satisfied with a model, you can finalize it for production and deploy it with ease.
#
# PyCaret is an excellent tool for both beginners and experienced data scientists, empowering them to build high-quality machine learning models efficiently.
#
# Give PyCaret a try and witness the speed and productivity it brings to your machine learning projects!
#
# For more information, visit the [PyCaret GitHub repository](https://github.com/pycaret/pycaret).

# %%
# This code is using the PyCaret library to perform regression modeling on a batsman dataset.

# The setup() function is used to prepare the data for modeling. 
# The batsman_df dataset is passed to the function, and the target parameter is set to 'd11', 
# which is the name of the column that contains the target variable to be predicted. 
# The train_size parameter is set to 0.1, which means that 10% of the data will be used for training 
# and the remaining 90% will be used for testing. The preprocess parameter is set to False, 
# which means that PyCaret will not perform any preprocessing on the data.

batsman_regression_setup = setup(
    batsman_df, target='d11', train_size=0.1, verbose=False, preprocess=False
)

# The compare_models() function is used to train and evaluate all available regression models in PyCaret
# on the batsman dataset. The best-performing model is automatically selected based on the metric specified
# in the sort parameter, which is set to the R-squared ('R2') in this case. The verbose parameter is set to
# True to print the results of each model.

best_batsman_model = compare_models(verbose=True)
compare_models(fold = 5,round = 4,sort = 'R2',turbo = True)
# Out:
# <style type="text/css">
# #T_6a8d0 th {
#   text-align: left;
# }
# #T_6a8d0_row0_col0, #T_6a8d0_row0_col1, #T_6a8d0_row0_col5, #T_6a8d0_row0_col6, #T_6a8d0_row1_col0, #T_6a8d0_row1_col1, #T_6a8d0_row1_col2, #T_6a8d0_row1_col3, #T_6a8d0_row1_col5, #T_6a8d0_row1_col6, #T_6a8d0_row2_col0, #T_6a8d0_row2_col1, #T_6a8d0_row2_col2, #T_6a8d0_row2_col3, #T_6a8d0_row2_col4, #T_6a8d0_row2_col5, #T_6a8d0_row2_col6, #T_6a8d0_row3_col0, #T_6a8d0_row3_col1, #T_6a8d0_row3_col2, #T_6a8d0_row3_col3, #T_6a8d0_row3_col4, #T_6a8d0_row3_col5, #T_6a8d0_row3_col6, #T_6a8d0_row4_col0, #T_6a8d0_row4_col1, #T_6a8d0_row4_col2, #T_6a8d0_row4_col3, #T_6a8d0_row4_col4, #T_6a8d0_row4_col5, #T_6a8d0_row4_col6, #T_6a8d0_row5_col0, #T_6a8d0_row5_col1, #T_6a8d0_row5_col2, #T_6a8d0_row5_col3, #T_6a8d0_row5_col4, #T_6a8d0_row5_col5, #T_6a8d0_row5_col6, #T_6a8d0_row6_col0, #T_6a8d0_row6_col2, #T_6a8d0_row6_col3, #T_6a8d0_row6_col4, #T_6a8d0_row6_col5, #T_6a8d0_row6_col6, #T_6a8d0_row7_col0, #T_6a8d0_row7_col1, #T_6a8d0_row7_col2, #T_6a8d0_row7_col3, #T_6a8d0_row7_col4, #T_6a8d0_row8_col0, #T_6a8d0_row8_col1, #T_6a8d0_row8_col2, #T_6a8d0_row8_col3, #T_6a8d0_row8_col4, #T_6a8d0_row8_col5, #T_6a8d0_row8_col6, #T_6a8d0_row9_col0, #T_6a8d0_row9_col1, #T_6a8d0_row9_col2, #T_6a8d0_row9_col3, #T_6a8d0_row9_col4, #T_6a8d0_row9_col5, #T_6a8d0_row9_col6, #T_6a8d0_row10_col0, #T_6a8d0_row10_col1, #T_6a8d0_row10_col2, #T_6a8d0_row10_col3, #T_6a8d0_row10_col4, #T_6a8d0_row10_col5, #T_6a8d0_row10_col6, #T_6a8d0_row11_col0, #T_6a8d0_row11_col1, #T_6a8d0_row11_col2, #T_6a8d0_row11_col3, #T_6a8d0_row11_col4, #T_6a8d0_row11_col5, #T_6a8d0_row11_col6, #T_6a8d0_row12_col0, #T_6a8d0_row12_col1, #T_6a8d0_row12_col2, #T_6a8d0_row12_col3, #T_6a8d0_row12_col4, #T_6a8d0_row12_col5, #T_6a8d0_row12_col6, #T_6a8d0_row13_col0, #T_6a8d0_row13_col1, #T_6a8d0_row13_col2, #T_6a8d0_row13_col3, #T_6a8d0_row13_col4, #T_6a8d0_row13_col5, #T_6a8d0_row13_col6, #T_6a8d0_row14_col0, #T_6a8d0_row14_col1, #T_6a8d0_row14_col2, #T_6a8d0_row14_col3, #T_6a8d0_row14_col4, #T_6a8d0_row14_col5, #T_6a8d0_row14_col6, #T_6a8d0_row15_col0, #T_6a8d0_row15_col1, #T_6a8d0_row15_col2, #T_6a8d0_row15_col3, #T_6a8d0_row15_col4, #T_6a8d0_row15_col5, #T_6a8d0_row15_col6, #T_6a8d0_row16_col0, #T_6a8d0_row16_col1, #T_6a8d0_row16_col2, #T_6a8d0_row16_col3, #T_6a8d0_row16_col4, #T_6a8d0_row16_col5, #T_6a8d0_row16_col6, #T_6a8d0_row17_col0, #T_6a8d0_row17_col1, #T_6a8d0_row17_col2, #T_6a8d0_row17_col3, #T_6a8d0_row17_col4, #T_6a8d0_row17_col5, #T_6a8d0_row17_col6, #T_6a8d0_row18_col0, #T_6a8d0_row18_col1, #T_6a8d0_row18_col2, #T_6a8d0_row18_col3, #T_6a8d0_row18_col4, #T_6a8d0_row18_col5, #T_6a8d0_row18_col6, #T_6a8d0_row19_col0, #T_6a8d0_row19_col1, #T_6a8d0_row19_col2, #T_6a8d0_row19_col3, #T_6a8d0_row19_col4, #T_6a8d0_row19_col5, #T_6a8d0_row19_col6 {
#   text-align: left;
# }
# #T_6a8d0_row0_col2, #T_6a8d0_row0_col3, #T_6a8d0_row0_col4, #T_6a8d0_row1_col4, #T_6a8d0_row6_col1, #T_6a8d0_row7_col5, #T_6a8d0_row7_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_6a8d0_row0_col7, #T_6a8d0_row1_col7, #T_6a8d0_row2_col7, #T_6a8d0_row3_col7, #T_6a8d0_row4_col7, #T_6a8d0_row5_col7, #T_6a8d0_row6_col7, #T_6a8d0_row7_col7, #T_6a8d0_row8_col7, #T_6a8d0_row9_col7, #T_6a8d0_row10_col7, #T_6a8d0_row11_col7, #T_6a8d0_row12_col7, #T_6a8d0_row13_col7, #T_6a8d0_row14_col7, #T_6a8d0_row15_col7, #T_6a8d0_row16_col7, #T_6a8d0_row18_col7, #T_6a8d0_row19_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_6a8d0_row17_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_6a8d0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6a8d0_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_6a8d0_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_6a8d0_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_6a8d0_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_6a8d0_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_6a8d0_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_6a8d0_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_6a8d0_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6a8d0_level0_row0" class="row_heading level0 row0" >lr</th>
#       <td id="T_6a8d0_row0_col0" class="data row0 col0" >Linear Regression</td>
#       <td id="T_6a8d0_row0_col1" class="data row0 col1" >0.9926</td>
#       <td id="T_6a8d0_row0_col2" class="data row0 col2" >1.8293</td>
#       <td id="T_6a8d0_row0_col3" class="data row0 col3" >1.3481</td>
#       <td id="T_6a8d0_row0_col4" class="data row0 col4" >0.9979</td>
#       <td id="T_6a8d0_row0_col5" class="data row0 col5" >0.2164</td>
#       <td id="T_6a8d0_row0_col6" class="data row0 col6" >0.1822</td>
#       <td id="T_6a8d0_row0_col7" class="data row0 col7" >1.9320</td>
#     </tr>
#     <tr>
#       <th id="T_6a8d0_level0_row1" class="row_heading level0 row1" >br</th>
#       <td id="T_6a8d0_row1_col0" class="data row1 col0" >Bayesian Ridge</td>
#       <td id="T_6a8d0_row1_col1" class="data row1 col1" >0.9958</td>
#       <td id="T_6a8d0_row1_col2" class="data row1 col2" >1.8309</td>
#       <td id="T_6a8d0_row1_col3" class="data row1 col3" >1.3490</td>
#       <td id="T_6a8d0_row1_col4" class="data row1 col4" >0.9979</td>
#       <td id="T_6a8d0_row1_col5" class="data row1 col5" >0.2160</td>
#       <td id="T_6a8d0_row1_col6" class="data row1 col6" >0.1819</td>
#       <td id="T_6a8d0_row1_col7" class="data row1 col7" >0.8290</td>
#     </tr>
#     <tr>
#       <th id="T_6a8d0_level0_row2" class="row_heading level0 row2" >ridge</th>
#       <td id="T_6a8d0_row2_col0" class="data row2 col0" >Ridge Regression</td>
#       <td id="T_6a8d0_row2_col1" class="data row2 col1" >1.0085</td>
#       <td id="T_6a8d0_row2_col2" class="data row2 col2" >1.8468</td>
#       <td id="T_6a8d0_row2_col3" class="data row2 col3" >1.3557</td>
#       <td id="T_6a8d0_row2_col4" class="data row2 col4" >0.9978</td>
#       <td id="T_6a8d0_row2_col5" class="data row2 col5" >0.2149</td>
#       <td id="T_6a8d0_row2_col6" class="data row2 col6" >0.1812</td>
#       <td id="T_6a8d0_row2_col7" class="data row2 col7" >1.0060</td>
#     </tr>
#     <tr>
#       <th id="T_6a8d0_level0_row3" class="row_heading level0 row3" >lar</th>
#       <td id="T_6a8d0_row3_col0" class="data row3 col0" >Least Angle Regression</td>
#       <td id="T_6a8d0_row3_col1" class="data row3 col1" >1.1111</td>
#       <td id="T_6a8d0_row3_col2" class="data row3 col2" >2.1800</td>
#       <td id="T_6a8d0_row3_col3" class="data row3 col3" >1.4671</td>
#       <td id="T_6a8d0_row3_col4" class="data row3 col4" >0.9975</td>
#       <td id="T_6a8d0_row3_col5" class="data row3 col5" >0.2260</td>
#       <td id="T_6a8d0_row3_col6" class="data row3 col6" >0.2028</td>
#       <td id="T_6a8d0_row3_col7" class="data row3 col7" >1.1560</td>
#     </tr>
#     <tr>
#       <th id="T_6a8d0_level0_row4" class="row_heading level0 row4" >xgboost</th>
#       <td id="T_6a8d0_row4_col0" class="data row4 col0" >Extreme Gradient Boosting</td>
#       <td id="T_6a8d0_row4_col1" class="data row4 col1" >0.5571</td>
#       <td id="T_6a8d0_row4_col2" class="data row4 col2" >3.3841</td>
#       <td id="T_6a8d0_row4_col3" class="data row4 col3" >1.4277</td>
#       <td id="T_6a8d0_row4_col4" class="data row4 col4" >0.9967</td>
#       <td id="T_6a8d0_row4_col5" class="data row4 col5" >0.0411</td>
#       <td id="T_6a8d0_row4_col6" class="data row4 col6" >0.0256</td>
#       <td id="T_6a8d0_row4_col7" class="data row4 col7" >1.0380</td>
#     </tr>
#     <tr>
#       <th id="T_6a8d0_level0_row5" class="row_heading level0 row5" >gbr</th>
#       <td id="T_6a8d0_row5_col0" class="data row5 col0" >Gradient Boosting Regressor</td>
#       <td id="T_6a8d0_row5_col1" class="data row5 col1" >0.6379</td>
#       <td id="T_6a8d0_row5_col2" class="data row5 col2" >3.4399</td>
#       <td id="T_6a8d0_row5_col3" class="data row5 col3" >1.3797</td>
#       <td
# <style type="text/css">
# #T_064a7 th {
#   text-align: left;
# }
# #T_064a7_row0_col0, #T_064a7_row0_col1, #T_064a7_row0_col5, #T_064a7_row0_col6, #T_064a7_row1_col0, #T_064a7_row1_col1, #T_064a7_row1_col2, #T_064a7_row1_col3, #T_064a7_row1_col5, #T_064a7_row1_col6, #T_064a7_row2_col0, #T_064a7_row2_col1, #T_064a7_row2_col2, #T_064a7_row2_col3, #T_064a7_row2_col5, #T_064a7_row2_col6, #T_064a7_row3_col0, #T_064a7_row3_col1, #T_064a7_row3_col2, #T_064a7_row3_col3, #T_064a7_row3_col4, #T_064a7_row3_col5, #T_064a7_row3_col6, #T_064a7_row4_col0, #T_064a7_row4_col1, #T_064a7_row4_col2, #T_064a7_row4_col3, #T_064a7_row4_col4, #T_064a7_row5_col0, #T_064a7_row5_col1, #T_064a7_row5_col2, #T_064a7_row5_col3, #T_064a7_row5_col4, #T_064a7_row5_col5, #T_064a7_row5_col6, #T_064a7_row6_col0, #T_064a7_row6_col1, #T_064a7_row6_col2, #T_064a7_row6_col3, #T_064a7_row6_col4, #T_064a7_row6_col5, #T_064a7_row6_col6, #T_064a7_row7_col0, #T_064a7_row7_col1, #T_064a7_row7_col2, #T_064a7_row7_col3, #T_064a7_row7_col4, #T_064a7_row7_col5, #T_064a7_row7_col6, #T_064a7_row8_col0, #T_064a7_row8_col1, #T_064a7_row8_col2, #T_064a7_row8_col3, #T_064a7_row8_col4, #T_064a7_row8_col5, #T_064a7_row8_col6, #T_064a7_row9_col0, #T_064a7_row9_col1, #T_064a7_row9_col2, #T_064a7_row9_col3, #T_064a7_row9_col4, #T_064a7_row9_col5, #T_064a7_row9_col6, #T_064a7_row10_col0, #T_064a7_row10_col1, #T_064a7_row10_col2, #T_064a7_row10_col3, #T_064a7_row10_col4, #T_064a7_row10_col5, #T_064a7_row10_col6, #T_064a7_row11_col0, #T_064a7_row11_col2, #T_064a7_row11_col3, #T_064a7_row11_col4, #T_064a7_row11_col5, #T_064a7_row11_col6, #T_064a7_row12_col0, #T_064a7_row12_col1, #T_064a7_row12_col2, #T_064a7_row12_col3, #T_064a7_row12_col4, #T_064a7_row12_col5, #T_064a7_row12_col6, #T_064a7_row13_col0, #T_064a7_row13_col1, #T_064a7_row13_col2, #T_064a7_row13_col3, #T_064a7_row13_col4, #T_064a7_row13_col5, #T_064a7_row13_col6, #T_064a7_row14_col0, #T_064a7_row14_col1, #T_064a7_row14_col2, #T_064a7_row14_col3, #T_064a7_row14_col4, #T_064a7_row14_col5, #T_064a7_row14_col6, #T_064a7_row15_col0, #T_064a7_row15_col1, #T_064a7_row15_col2, #T_064a7_row15_col3, #T_064a7_row15_col4, #T_064a7_row15_col5, #T_064a7_row15_col6, #T_064a7_row16_col0, #T_064a7_row16_col1, #T_064a7_row16_col2, #T_064a7_row16_col3, #T_064a7_row16_col4, #T_064a7_row16_col5, #T_064a7_row16_col6, #T_064a7_row17_col0, #T_064a7_row17_col1, #T_064a7_row17_col2, #T_064a7_row17_col3, #T_064a7_row17_col4, #T_064a7_row17_col5, #T_064a7_row17_col6, #T_064a7_row18_col0, #T_064a7_row18_col1, #T_064a7_row18_col2, #T_064a7_row18_col3, #T_064a7_row18_col4, #T_064a7_row18_col5, #T_064a7_row18_col6, #T_064a7_row19_col0, #T_064a7_row19_col1, #T_064a7_row19_col2, #T_064a7_row19_col3, #T_064a7_row19_col4, #T_064a7_row19_col5, #T_064a7_row19_col6 {
#   text-align: left;
# }
# #T_064a7_row0_col2, #T_064a7_row0_col3, #T_064a7_row0_col4, #T_064a7_row1_col4, #T_064a7_row2_col4, #T_064a7_row4_col5, #T_064a7_row4_col6, #T_064a7_row11_col1 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_064a7_row0_col7, #T_064a7_row1_col7, #T_064a7_row3_col7, #T_064a7_row4_col7, #T_064a7_row5_col7, #T_064a7_row6_col7, #T_064a7_row7_col7, #T_064a7_row8_col7, #T_064a7_row9_col7, #T_064a7_row10_col7, #T_064a7_row11_col7, #T_064a7_row12_col7, #T_064a7_row13_col7, #T_064a7_row14_col7, #T_064a7_row15_col7, #T_064a7_row16_col7, #T_064a7_row17_col7, #T_064a7_row18_col7, #T_064a7_row19_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_064a7_row2_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_064a7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_064a7_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_064a7_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_064a7_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_064a7_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_064a7_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_064a7_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_064a7_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_064a7_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_064a7_level0_row0" class="row_heading level0 row0" >lr</th>
#       <td id="T_064a7_row0_col0" class="data row0 col0" >Linear Regression</td>
#       <td id="T_064a7_row0_col1" class="data row0 col1" >0.9907</td>
#       <td id="T_064a7_row0_col2" class="data row0 col2" >1.8188</td>
#       <td id="T_064a7_row0_col3" class="data row0 col3" >1.3469</td>
#       <td id="T_064a7_row0_col4" class="data row0 col4" >0.9979</td>
#       <td id="T_064a7_row0_col5" class="data row0 col5" >0.2174</td>
#       <td id="T_064a7_row0_col6" class="data row0 col6" >0.1816</td>
#       <td id="T_064a7_row0_col7" class="data row0 col7" >1.2320</td>
#     </tr>
#     <tr>
#       <th id="T_064a7_level0_row1" class="row_heading level0 row1" >ridge</th>
#       <td id="T_064a7_row1_col0" class="data row1 col0" >Ridge Regression</td>
#       <td id="T_064a7_row1_col1" class="data row1 col1" >1.0082</td>
#       <td id="T_064a7_row1_col2" class="data row1 col2" >1.8415</td>
#       <td id="T_064a7_row1_col3" class="data row1 col3" >1.3559</td>
#       <td id="T_064a7_row1_col4" class="data row1 col4" >0.9979</td>
#       <td id="T_064a7_row1_col5" class="data row1 col5" >0.2157</td>
#       <td id="T_064a7_row1_col6" class="data row1 col6" >0.1806</td>
#       <td id="T_064a7_row1_col7" class="data row1 col7" >0.7380</td>
#     </tr>
#     <tr>
#       <th id="T_064a7_level0_row2" class="row_heading level0 row2" >br</th>
#       <td id="T_064a7_row2_col0" class="data row2 col0" >Bayesian Ridge</td>
#       <td id="T_064a7_row2_col1" class="data row2 col1" >0.9942</td>
#       <td id="T_064a7_row2_col2" class="data row2 col2" >1.8212</td>
#       <td id="T_064a7_row2_col3" class="data row2 col3" >1.3479</td>
#       <td id="T_064a7_row2_col4" class="data row2 col4" >0.9979</td>
#       <td id="T_064a7_row2_col5" class="data row2 col5" >0.2169</td>
#       <td id="T_064a7_row2_col6" class="data row2 col6" >0.1812</td>
#       <td id="T_064a7_row2_col7" class="data row2 col7" >0.5460</td>
#     </tr>
#     <tr>
#       <th id="T_064a7_level0_row3" class="row_heading level0 row3" >gbr</th>
#       <td id="T_064a7_row3_col0" class="data row3 col0" >Gradient Boosting Regressor</td>
#       <td id="T_064a7_row3_col1" class="data row3 col1" >0.6442</td>
#       <td id="T_064a7_row3_col2" class="data row3 col2" >3.3280</td>
#       <td id="T_064a7_row3_col3" class="data row3 col3" >1.5267</td>
#       <td id="T_064a7_row3_col4" class="data row3 col4" >0.9964</td>
#       <td id="T_064a7_row3_col5" class="data row3 col5" >0.0851</td>
#       <td id="T_064a7_row3_col6" class="data row3 col6" >0.0577</td>
#       <td id="T_064a7_row3_col7" class="data row3 col7" >0.7480</td>
#     </tr>
#     <tr>
#       <th id="T_064a7_level0_row4" class="row_heading level0 row4" >et</th>
#       <td id="T_064a7_row4_col0" class="data row4 col0" >Extra Trees Regressor</td>
#       <td id="T_064a7_row4_col1" class="data row4 col1" >0.6332</td>
#       <td id="T_064a7_row4_col2" class="data row4 col2" >3.7144</td>
#       <td id="T_064a7_row4_col3" class="data row4 col3" >1.6243</td>
#       <td id="T_064a7_row4_col4" class="data row4 col4" >0.9960</td>
#       <td id="T_064a7_row4_col5" class="data row4 col5" >0.0371</td>
#       <td id="T_064a7_row4_col6" class="data row4 col6" >0.0223</td>
#       <td id="T_064a7_row4_col7" class="data row4 col7" >0.8160</td>
#     </tr>
#     <tr>
#       <th id="T_064a7_level0_row5" class="row_heading level0 row5" >xgboost</th>
#       <td id="T_064a7_row5_col0" class="data row5 col0" >Extreme Gradient Boosting</td>
#       <td id="T_064a7_row5_col1" class="data row5 col1" >0.6486</td>
#       <td id="T_064a7_row5_col2" class="data row5 col2" >3.7861</td>
#       <td id="T_064a7_row5_col3" class="data row5 col3" >1.7099</td>
#       <td i
# LinearRegression(n_jobs=-1)

# %%
# After the best-performing model is identified, the create_model() function is used to create a model of the
# same type as the best-performing model. In this case, the 'lr' model type, which stands for 
# Linear Regression, is selected. The fold parameter is set to 5 to perform 5-fold cross-validation
# during training.
batsman_lr_model = create_model('lr', fold=5)

# Finally, the save_model() function is used to save the trained model to a file named 
# 'batsman_Linear_Regression_model'. This file can be loaded later to make predictions on new data.
save_model(batsman_lr_model, 'batsman_Linear_Regression_model')
# Out:
# <style type="text/css">
# #T_dcd55_row5_col0, #T_dcd55_row5_col1, #T_dcd55_row5_col2, #T_dcd55_row5_col3, #T_dcd55_row5_col4, #T_dcd55_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_dcd55">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dcd55_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_dcd55_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_dcd55_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_dcd55_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_dcd55_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_dcd55_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dcd55_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dcd55_row0_col0" class="data row0 col0" >1.0032</td>
#       <td id="T_dcd55_row0_col1" class="data row0 col1" >1.6692</td>
#       <td id="T_dcd55_row0_col2" class="data row0 col2" >1.2920</td>
#       <td id="T_dcd55_row0_col3" class="data row0 col3" >0.9983</td>
#       <td id="T_dcd55_row0_col4" class="data row0 col4" >0.2269</td>
#       <td id="T_dcd55_row0_col5" class="data row0 col5" >0.1599</td>
#     </tr>
#     <tr>
#       <th id="T_dcd55_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_dcd55_row1_col0" class="data row1 col0" >1.0075</td>
#       <td id="T_dcd55_row1_col1" class="data row1 col1" >1.8233</td>
#       <td id="T_dcd55_row1_col2" class="data row1 col2" >1.3503</td>
#       <td id="T_dcd55_row1_col3" class="data row1 col3" >0.9978</td>
#       <td id="T_dcd55_row1_col4" class="data row1 col4" >0.2396</td>
#       <td id="T_dcd55_row1_col5" class="data row1 col5" >0.1833</td>
#     </tr>
#     <tr>
#       <th id="T_dcd55_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_dcd55_row2_col0" class="data row2 col0" >0.9810</td>
#       <td id="T_dcd55_row2_col1" class="data row2 col1" >2.1597</td>
#       <td id="T_dcd55_row2_col2" class="data row2 col2" >1.4696</td>
#       <td id="T_dcd55_row2_col3" class="data row2 col3" >0.9972</td>
#       <td id="T_dcd55_row2_col4" class="data row2 col4" >0.1816</td>
#       <td id="T_dcd55_row2_col5" class="data row2 col5" >0.1913</td>
#     </tr>
#     <tr>
#       <th id="T_dcd55_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_dcd55_row3_col0" class="data row3 col0" >0.9710</td>
#       <td id="T_dcd55_row3_col1" class="data row3 col1" >1.6156</td>
#       <td id="T_dcd55_row3_col2" class="data row3 col2" >1.2711</td>
#       <td id="T_dcd55_row3_col3" class="data row3 col3" >0.9981</td>
#       <td id="T_dcd55_row3_col4" class="data row3 col4" >0.2262</td>
#       <td id="T_dcd55_row3_col5" class="data row3 col5" >0.2008</td>
#     </tr>
#     <tr>
#       <th id="T_dcd55_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_dcd55_row4_col0" class="data row4 col0" >0.9909</td>
#       <td id="T_dcd55_row4_col1" class="data row4 col1" >1.8263</td>
#       <td id="T_dcd55_row4_col2" class="data row4 col2" >1.3514</td>
#       <td id="T_dcd55_row4_col3" class="data row4 col3" >0.9981</td>
#       <td id="T_dcd55_row4_col4" class="data row4 col4" >0.2126</td>
#       <td id="T_dcd55_row4_col5" class="data row4 col5" >0.1726</td>
#     </tr>
#     <tr>
#       <th id="T_dcd55_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_dcd55_row5_col0" class="data row5 col0" >0.9907</td>
#       <td id="T_dcd55_row5_col1" class="data row5 col1" >1.8188</td>
#       <td id="T_dcd55_row5_col2" class="data row5 col2" >1.3469</td>
#       <td id="T_dcd55_row5_col3" class="data row5 col3" >0.9979</td>
#       <td id="T_dcd55_row5_col4" class="data row5 col4" >0.2174</td>
#       <td id="T_dcd55_row5_col5" class="data row5 col5" >0.1816</td>
#     </tr>
#     <tr>
#       <th id="T_dcd55_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_dcd55_row6_col0" class="data row6 col0" >0.0136</td>
#       <td id="T_dcd55_row6_col1" class="data row6 col1" >0.1897</td>
#       <td id="T_dcd55_row6_col2" class="data row6 col2" >0.0691</td>
#       <td id="T_dcd55_row6_col3" class="data row6 col3" >0.0004</td>
#       <td id="T_dcd55_row6_col4" class="data row6 col4" >0.0198</td>
#       <td id="T_dcd55_row6_col5" class="data row6 col5" >0.0143</td>
#     </tr>
#   </tbody>
# </table>
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=FastMemory(location=C:\Users\harsh\AppData\Local\Temp\joblib),
#           steps=[('placeholder', None),
#                  ('trained_model', LinearRegression(n_jobs=-1))]),
#  'batsman_Linear_Regression_model.pkl')

# %%
# This code is using the PyCaret library to perform regression modeling on a batsman dataset.

# The setup() function is used to prepare the data for modeling. 
# The bowler_df dataset is passed to the function, and the target parameter is set to 'd11', 
# which is the name of the column that contains the target variable to be predicted. 
# The train_size parameter is set to 0.1, which means that 10% of the data will be used for training 
# and the remaining 90% will be used for testing. The preprocess parameter is set to False, 
# which means that PyCaret will not perform any preprocessing on the data.

bowler_regression_setup = setup(
    bowler_df, target='d11', train_size=0.1, verbose=False, preprocess=False
)

# The compare_models() function is used to train and evaluate all available regression models in PyCaret
# on the bowler dataset. The best-performing model is automatically selected based on the metric specified
# in the sort parameter, which is set to the R-squared ('R2') in this case. The verbose parameter is set to
# True to print the results of each model.

best_bowler_model = compare_models(verbose=True)
compare_models(fold = 5,round = 4,sort = 'R2',turbo = True)
# Out:
# <style type="text/css">
# #T_e918f th {
#   text-align: left;
# }
# #T_e918f_row0_col0, #T_e918f_row1_col0, #T_e918f_row1_col1, #T_e918f_row1_col2, #T_e918f_row1_col3, #T_e918f_row1_col4, #T_e918f_row1_col5, #T_e918f_row1_col6, #T_e918f_row2_col0, #T_e918f_row2_col1, #T_e918f_row2_col2, #T_e918f_row2_col3, #T_e918f_row2_col4, #T_e918f_row2_col5, #T_e918f_row2_col6, #T_e918f_row3_col0, #T_e918f_row3_col1, #T_e918f_row3_col2, #T_e918f_row3_col3, #T_e918f_row3_col4, #T_e918f_row3_col5, #T_e918f_row3_col6, #T_e918f_row4_col0, #T_e918f_row4_col1, #T_e918f_row4_col2, #T_e918f_row4_col3, #T_e918f_row4_col4, #T_e918f_row4_col5, #T_e918f_row4_col6, #T_e918f_row5_col0, #T_e918f_row5_col1, #T_e918f_row5_col2, #T_e918f_row5_col3, #T_e918f_row5_col4, #T_e918f_row5_col5, #T_e918f_row5_col6, #T_e918f_row6_col0, #T_e918f_row6_col1, #T_e918f_row6_col2, #T_e918f_row6_col3, #T_e918f_row6_col4, #T_e918f_row6_col5, #T_e918f_row6_col6, #T_e918f_row7_col0, #T_e918f_row7_col1, #T_e918f_row7_col2, #T_e918f_row7_col3, #T_e918f_row7_col4, #T_e918f_row7_col5, #T_e918f_row7_col6, #T_e918f_row8_col0, #T_e918f_row8_col1, #T_e918f_row8_col2, #T_e918f_row8_col3, #T_e918f_row8_col4, #T_e918f_row8_col5, #T_e918f_row8_col6, #T_e918f_row9_col0, #T_e918f_row9_col1, #T_e918f_row9_col2, #T_e918f_row9_col3, #T_e918f_row9_col4, #T_e918f_row9_col5, #T_e918f_row9_col6, #T_e918f_row10_col0, #T_e918f_row10_col1, #T_e918f_row10_col2, #T_e918f_row10_col3, #T_e918f_row10_col4, #T_e918f_row10_col5, #T_e918f_row10_col6, #T_e918f_row11_col0, #T_e918f_row11_col1, #T_e918f_row11_col2, #T_e918f_row11_col3, #T_e918f_row11_col4, #T_e918f_row11_col5, #T_e918f_row11_col6, #T_e918f_row12_col0, #T_e918f_row12_col1, #T_e918f_row12_col2, #T_e918f_row12_col3, #T_e918f_row12_col4, #T_e918f_row12_col5, #T_e918f_row12_col6, #T_e918f_row13_col0
row4_col0" class="data row4 col0" >Decision Tree Regressor</td>
#       <td id="T_6bc17_row4_col1" class="data row4 col1" >0.0234</td>
#       <td id="T_6bc17_row4_col2" class="data row4 col2" >0.2813</td>
#       <td id="T_6bc17_row4_col3" class="data row4 col3" >0.2372</td>
#       <td id="T_6bc17_row4_col4" class="data row4 col4" >0.9985</td>
#       <td id="T_6bc17_row4_col5" class="data row4 col5" >0.0056</td>
#       <td id="T_6bc17_row4_col6" class="data row4 col6" >0.0008</td>
#       <td id="T_6bc17_row4_col7" class="data row4 col7" >0.6320</td>
#     </tr>
#     <tr>
#       <th id="T_6bc17_level0_row5" class="row_heading level0 row5" >lightgbm</th>
#       <td id="T_6bc17_row5_col0" class="data row5 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_6bc17_row5_col1" class="data row5 col1" >0.1917</td>
#       <td id="T_6bc17_row5_col2" class="data row5 col2" >0.4202</td>
#       <td id="T_6bc17_row5_col3" class="data ro
# GradientBoostingRegressor(random_state=4015)

# %%
# Create the Gradient Boosting Regressor model for the bowler dataset using the top-performing model's hyperparameters
bowler_gbr_model = create_model('gbr', fold=5)

# Save the trained Gradient Boosting Regressor model for the bowler dataset to a file
save_model(bowler_gbr_model, 'bowler_Gradient_Boosting_Regressor_model')
# Out:
# <style type="text/css">
# #T_2276b_row5_col0, #T_2276b_row5_col1, #T_2276b_row5_col2, #T_2276b_row5_col3, #T_2276b_row5_col4, #T_2276b_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_2276b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2276b_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_2276b_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_2276b_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_2276b_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_2276b_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_2276b_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2276b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2276b_row0_col0" class="data row0 col0" >0.0006</td>
#       <td id="T_2276b_row0_col1" class="data row0 col1" >0.0000</td>
#       <td id="T_2276b_row0_col2" class="data row0 col2" >0.0020</td>
#       <td id="T_2276b_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_2276b_row0_col4" class="data row0 col4" >0.0004</td>
#       <td id="T_2276b_row0_col5" class="data row0 col5" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_2276b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2276b_row1_col0" class="data row1 col0" >0.0008</td>
#       <td id="T_2276b_row1_col1" class="data row1 col1" >0.0000</td>
#       <td id="T_2276b_row1_col2" class="data row1 col2" >0.0037</td>
#       <td id="T_2276b_row1_col3" class="data row1 col3" >1.0000</td>
#       <td id="T_2276b_row1_col4" class="data row1 col4" >0.0004</td>
#       <td id="T_2276b_row1_col5" class="data row1 col5" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_2276b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2276b_row2_col0" class="data row2 col0" >0.0010</td>
#       <td id="T_2276b_row2_col1" class="data row2 col1" >0.0001</td>
#       <td id="T_2276b_row2_col2" class="data row2 col2" >0.0086</td>
#       <td id="T_2276b_row2_col3" class="data row2 col3" >1.0000</td>
#       <td id="T_2276b_row2_col4" class="data row2 col4" >0.0005</td>
#       <td id="T_2276b_row2_col5" class="data row2 col5" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_2276b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2276b_row3_col0" class="data row3 col0" >0.0649</td>
#       <td id="T_2276b_row3_col1" class="data row3 col1" >0.3714</td>
#       <td id="T_2276b_row3_col2" class="data row3 col2" >0.6094</td>
#       <td id="T_2276b_row3_col3" class="data row3 col3" >0.9980</td>
#       <td id="T_2276b_row3_col4" class="data row3 col4" >0.0134</td>
#       <td id="T_2276b_row3_col5" class="data row3 col5" >0.0024</td>
#     </tr>
#     <tr>
#       <th id="T_2276b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2276b_row4_col0" class="data row4 col0" >0.0042</td>
#       <td id="T_2276b_row4_col1" class="data row4 col1" >0.0020</td>
#       <td id="T_2276b_row4_col2" class="data row4 col2" >0.0450</td>
#       <td id="T_2276b_row4_col3" class="data row4 col3" >1.0000</td>
#       <td id="T_2276b_row4_col4" class="data row4 col4" >0.0014</td>
#       <td id="T_2276b_row4_col5" class="data row4 col5" >0.0002</td>
#     </tr>
#     <tr>
#       <th id="T_2276b_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_2276b_row5_col0" class="data row5 col0" >0.0143</td>
#       <td id="T_2276b_row5_col1" class="data row5 col1" >0.0747</td>
#       <td id="T_2276b_row5_col2" class="data row5 col2" >0.1338</td>
#       <td id="T_2276b_row5_col3" class="data row5 col3" >0.9996</td>
#       <td id="T_2276b_row5_col4" class="data row5 col4" >0.0032</td>
#       <td id="T_2276b_row5_col5" class="data row5 col5" >0.0005</td>
#     </tr>
#     <tr>
#       <th id="T_2276b_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_2276b_row6_col0" class="data row6 col0" >0.0253</td>
#       <td id="T_2276b_row6_col1" class="data row6 col1" >0.1483</td>
#       <td id="T_2276b_row6_col2" class="data row6 col2" >0.2383</td>
#       <td id="T_2276b_row6_col3" class="data row6 col3" >0.0008</td>
#       <td id="T_2276b_row6_col4" class="data row6 col4" >0.0051</td>
#       <td id="T_2276b_row6_col5" class="data row6 col5" >0.0009</td>
#     </tr>
#   </tbody>
# </table>
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=FastMemory(location=C:\Users\harsh\AppData\Local\Temp\joblib),
#           steps=[('placeholder', None),
#                  ('trained_model',
#                   GradientBoostingRegressor(random_state=4015))]),
#  'bowler_Gradient_Boosting_Regressor_model.pkl')

# %%
# Split the datasets into train and test sets
train_batsman_df, test_batsman_df = train_test_split(
    batsman_df, test_size=0.2, random_state=42
)
train_bowler_df, test_bowler_df = train_test_split(
    bowler_df, test_size=0.2, random_state=42
)

# %%
X_train_batsman = train_batsman_df.iloc[:,:-1]
y_train_batsman = train_batsman_df.iloc[:,-1:]

X_test_batsman = test_batsman_df.iloc[:,:-1]
y_test_batsman = test_batsman_df.iloc[:,-1:]

X_train_bowler = train_bowler_df.iloc[:,:-1]
y_train_bowler = train_bowler_df.iloc[:,-1:]

X_test_bowler = test_bowler_df.iloc[:,:-1]
y_test_bowler = test_bowler_df.iloc[:,-1:]

# %%
# Print X_train_batsman column names
print("X_train Batsman Columns:")
print(X_train_batsman.columns)

# Print y_train_batsman column names
print("y_train Batsman Columns:")
print(y_train_batsman.columns)

# Print X_train_bowler column names
print("X_train Bowler Columns:")
print(X_train_bowler.columns)

# Print y_train_bowler column names
print("y_train Bowler Columns:")
print(y_train_bowler.columns)
# Out:
# X_train Batsman Columns:
# Index(['player', 'runs', 'balls', '4s', '6s', 'SR', 'bowler', 'fielders',
#        'kind', 'player_out', 'date', 'team2', 'winner', 'result', 'venue',
#        'team1', 'MF', '30s', '50s', '100s', '0s'],
#       dtype='object')
# y_train Batsman Columns:
# Index(['d11'], dtype='object')
# X_train Bowler Columns:
# Index(['player', 'overs', 'runs', 'maidens', 'wicket', 'econrate', 'date',
#        'team2', 'winner', 'result', 'venue', 'team1', 'MF', '3_wicket_haul',
#        '4_wicket_haul', '5_wicket_haul'],
#       dtype='object')
# y_train Bowler Columns:
# Index(['d11'], dtype='object')

# %%
## Predicting for batsman
batsman_lr_model.fit(X_train_batsman, y_train_batsman)
pred = batsman_lr_model.predict(X_test_batsman)
r2 = r2_score(pred,y_test_batsman)
print('The r2 using gbr is:',r2)
# Out:
# The r2 using gbr is: 0.9978683960678743

# %%
## Predicting for bowler
bowler_gbr_model.fit(X_train_bowler, y_train_bowler)
pred = bowler_gbr_model.predict(X_test_bowler)
r2 = r2_score(pred,y_test_bowler)
print('The r2 using gbr is:',r2)
# Out:
# The r2 using gbr is: 0.9999999797046697
