# %%
import pandas as pd
import numpy as np

from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

from pycaret.regression import setup, compare_models, create_model, save_model

# %%
## Importing dataset

batsman_df = pd.read_csv(r"C:\Users\Harsh\Documents\dream11\ipl\Merged Batting CSV\batting.csv")
bowler_df = pd.read_csv(r"C:\Users\Harsh\Documents\dream11\ipl\Merged Bowling CSV\bowling.csv")

# %%
# Converting object data types to categorical variables

# get list of categorical columns
cat_cols = batsman_df.select_dtypes(include=['object']).columns.tolist()
le = LabelEncoder()
for col in cat_cols:
    le.fit(batsman_df[col])
    batsman_df[col] = le.transform(batsman_df[col])

# %%
# Converting object data types to categorical variables

# get list of categorical columns
cat_cols = bowler_df.select_dtypes(include=['object']).columns.tolist()
for col in cat_cols:
    le.fit(bowler_df[col])
    bowler_df[col] = le.transform(bowler_df[col])

# %%
print(batsman_df.isna().sum())
print(bowler_df.isna().sum())
# Out:
# player        0
# runs          0
# balls         0
# 4s            0
# 6s            0
# SR            0
# bowler        0
# fielders      0
# kind          0
# player_out    0
# date          0
# team2         0
# winner        0
# result        0
# venue         0
# team1         0
# MF            0
# 30s           0
# 50s           0
# 100s          0
# 0s            0
# d11           0
# dtype: int64
# player            0
# overs             0
# runs              0
# maidens           0
# wicket            0
# econrate         11
# date              0
# team2             0
# winner            0
# result            0
# venue             0
# team1             0
# MF                0
# 3_wicket_haul     0
# 4_wicket_haul     0
# 5_wicket_haul     0
# d11               0
# dtype: int64

# %%
# Replacing na values with mean 
bowler_df.fillna(bowler_df.mean(), inplace=True)
print(bowler_df.isna().sum())
# Out:
# player           0
# overs            0
# runs             0
# maidens          0
# wicket           0
# econrate         0
# date             0
# team2            0
# winner           0
# result           0
# venue            0
# team1            0
# MF               0
# 3_wicket_haul    0
# 4_wicket_haul    0
# 5_wicket_haul    0
# d11              0
# dtype: int64

# %%
# Checking whether any infinity value
print("For batsman:")
print(np.isinf(batsman_df).any())
print("For bowler:")
print(np.isinf(bowler_df).any())
# Out:
# For batsman:
# player        False
# runs          False
# balls         False
# 4s            False
# 6s            False
# SR            False
# bowler        False
# fielders      False
# kind          False
# player_out    False
# date          False
# team2         False
# winner        False
# result        False
# venue         False
# team1         False
# MF            False
# 30s           False
# 50s           False
# 100s          False
# 0s            False
# d11           False
# dtype: bool
# For bowler:
# player           False
# overs            False
# runs             False
# maidens          False
# wicket           False
# econrate          True
# date             False
# team2            False
# winner           False
# result           False
# venue            False
# team1            False
# MF               False
# 3_wicket_haul    False
# 4_wicket_haul    False
# 5_wicket_haul    False
# d11              False
# dtype: bool

# %%
# replace infinity values in the 'column_name' column with the mean of the column
column_mean = bowler_df['econrate'].replace([np.inf, -np.inf], np.nan).mean()
bowler_df['econrate'].replace([np.inf, -np.inf], column_mean, inplace=True)
print(np.isinf(bowler_df).any())
# Out:
# player           False
# overs            False
# runs             False
# maidens          False
# wicket           False
# econrate         False
# date             False
# team2            False
# winner           False
# result           False
# venue            False
# team1            False
# MF               False
# 3_wicket_haul    False
# 4_wicket_haul    False
# 5_wicket_haul    False
# d11              False
# dtype: bool

# %%
num_unique_venues = len(batsman_df['venue'].unique())
print(f"The 'venue' column has {num_unique_venues} unique values.")
venue_grouped_batsman = batsman_df.groupby(['player','venue'])['d11'].mean()
venue_grouped_batsman
# Out:
# The 'venue' column has 49 unique values.
# player  venue
# 0       9        24.5
#         11        8.0
#         13       28.0
#         19       30.5
#         22       32.5
#                  ...
# 604     22       27.0
#         29        4.0
#         33        0.5
#         35        2.0
#         38       -1.0
# Name: d11, Length: 5465, dtype: float64

# %%
num_unique_venues = len(bowler_df['venue'].unique())
print(f"The 'venue' column has {num_unique_venues} unique values.")
venue_grouped_bowler = bowler_df.groupby(['player','venue'])['d11'].mean()
venue_grouped_bowler
# Out:
# The 'venue' column has 49 unique values.
# player  venue
# 0       2        25.000
#         9        12.500
#         11       25.000
#         19       12.500
#         22       12.500
#                   ...
# 471     40        0.000
#         41       25.000
#         42       25.000
#         43       25.000
#         46       16.625
# Name: d11, Length: 4379, dtype: float64

# %%
venue_grouped_batsman = pd.DataFrame(venue_grouped_batsman)
venue_grouped_bowler = pd.DataFrame(venue_grouped_bowler)

# %%
venue_grouped_batsman.reset_index(inplace = True)
venue_grouped_batsman
# Out:
#       player  venue   d11
# 0          0      9  24.5
# 1          0     11   8.0
# 2          0     13  28.0
# 3          0     19  30.5
# 4          0     22  32.5
# ...      ...    ...   ...
# 5460     604     22  27.0
# 5461     604     29   4.0
# 5462     604     33   0.5
# 5463     604     35   2.0
# 5464     604     38  -1.0
#
# [5465 rows x 3 columns]

# %%
venue_grouped_bowler.reset_index(inplace = True)
venue_grouped_bowler
# Out:
#       player  venue     d11
# 0          0      2  25.000
# 1          0      9  12.500
# 2          0     11  25.000
# 3          0     19  12.500
# 4          0     22  12.500
# ...      ...    ...     ...
# 4374     471     40   0.000
# 4375     471     41  25.000
# 4376     471     42  25.000
# 4377     471     43  25.000
# 4378     471     46  16.625
#
# [4379 rows x 3 columns]

# %% [markdown]
# ### PyCaret: A Low-Code Machine Learning Library in Python
#
# PyCaret is a powerful open-source, low-code machine learning library in Python that streamlines the entire machine learning workflow. With PyCaret, you can automate various aspects of machine learning experiments, saving you time and making you more productive.
#
# #### Key Features and Benefits
#
# - End-to-End Machine Learning: PyCaret provides a seamless end-to-end machine learning experience, handling data preprocessing, feature engineering, model training, hyperparameter tuning, and model evaluation.
#
# - Rapid Experimentation: Replace hundreds of lines of code with just a few words! PyCaret enables you to quickly iterate through different models and configurations, making experiments exponentially fast and efficient.
#
# - Integration with Popular Libraries: PyCaret acts as a convenient Python wrapper around various well-known machine learning libraries and frameworks, including scikit-learn, XGBoost, LightGBM, CatBoost, Optuna, Hyperopt, Ray, and more.
#
# #### How PyCaret Works
#
# 1. **Import the Library**: Start by importing the PyCaret library into your Python environment.
#
# 2. **Load and Preprocess Data**: Load your dataset and perform necessary data preprocessing using PyCaret's simple interface.
#
# 3. **Setup the Experiment**: With just one line of code, set up your machine learning experiment, specifying the target variable and any additional configuration settings.
#
# 4. **Compare Models**: PyCaret lets you quickly compare multiple models with minimal effort, so you can identify the best-performing ones.
#
# 5. **Tune Hyperparameters**: Utilize PyCaret's built-in hyperparameter tuning capabilities to fine-tune your models and improve their performance.
#
# 6. **Evaluate and Analyze Results**: PyCaret provides comprehensive model evaluation metrics and visualizations, making it easy to analyze the results of your experiments.
#
# 7. **Finalize and Deploy Models**: Once you're satisfied with a model, you can finalize it for production and deploy it with ease.
#
# PyCaret is an excellent tool for both beginners and experienced data scientists, empowering them to build high-quality machine learning models efficiently.
#
# Give PyCaret a try and witness the speed and productivity it brings to your machine learning projects!
#
# For more information, visit the [PyCaret GitHub repository](https://github.com/pycaret/pycaret).

# %%
# Set up the PyCaret environment for the batsman dataset
# Make sure to replace 'target' with the name of the target column (the one you want to predict)
batsman_regression_setup = setup(
    data=venue_grouped_batsman, target='d11',train_size=0.7, verbose=False, preprocess=False
)
# Compare all models and print the results for the batsman dataset
best_batsman_model = compare_models(fold = 5, round = 4, sort = 'R2', turbo = True, verbose=True)
# Out:
# <style type="text/css">
# #T_9de09 th {
#   text-align: left;
# }
# #T_9de09_row0_col0, #T_9de09_row0_col5, #T_9de09_row0_col6, #T_9de09_row1_col0, #T_9de09_row1_col1, #T_9de09_row1_col2, #T_9de09_row1_col3, #T_9de09_row1_col4, #T_9de09_row1_col5, #T_9de09_row1_col6, #T_9de09_row2_col0, #T_9de09_row2_col1, #T_9de09_row2_col2, #T_9de09_row2_col3, #T_9de09_row2_col4, #T_9de09_row2_col5, #T_9de09_row2_col6, #T_9de09_row3_col0, #T_9de09_row3_col1, #T_9de09_row3_col2, #T_9de09_row3_col3, #T_9de09_row3_col4, #T_9de09_row4_col0, #T_9de09_row4_col1, #T_9de09_row4_col2, #T_9de09_row4_col3, #T_9de09_row4_col4, #T_9de09_row4_col5, #T_9de09_row4_col6, #T_9de09_row5_col0, #T_9de09_row5_col1, #T_9de09_row5_col2, #T_9de09_row5_col3, #T_9de09_row5_col4, #T_9de09_row5_col5, #T_9de09_row5_col6, #T_9de09_row6_col0, #T_9de09_row6_col1, #T_9de09_row6_col2, #T_9de09_row6_col3, #T_9de09_row6_col4, #T_9de09_row6_col5, #T_9de09_row6_col6, #T_9de09_row7_col0, #T_9de09_row7_col1, #T_9de09_row7_col2, #T_9de09_row7_col3, #T_9de09_row7_col4, #T_9de09_row7_col5, #T_9de09_row7_col6, #T_9de09_row8_col0, #T_9de09_row8_col1, #T_9de09_row8_col2, #T_9de09_row8_col3, #T_9de09_row8_col4, #T_9de09_row8_col5, #T_9de09_row8_col6, #T_9de09_row9_col0, #T_9de09_row9_col1, #T_9de09_row9_col2, #T_9de09_row9_col3, #T_9de09_row9_col4, #T_9de09_row9_col5, #T_9de09_row9_col6, #T_9de09_row10_col0, #T_9de09_row10_col1, #T_9de09_row10_col2, #T_9de09_row10_col3, #T_9de09_row10_col4, #T_9de09_row10_col5, #T_9de09_row10_col6, #T_9de09_row11_col0, #T_9de09_row11_col1, #T_9de09_row11_col2, #T_9de09_row11_col3, #T_9de09_row11_col4, #T_9de09_row11_col5, #T_9de09_row11_col6, #T_9de09_row12_col0, #T_9de09_row12_col1, #T_9de09_row12_col2, #T_9de09_row12_col3, #T_9de09_row12_col4, #T_9de09_row12_col5, #T_9de09_row12_col6, #T_9de09_row13_col0, #T_9de09_row13_col1, #T_9de09_row13_col2, #T_9de09_row13_col3, #T_9de09_row13_col4, #T_9de09_row13_col5, #T_9de09_row13_col6, #T_9de09_row14_col0, #T_9de09_row14_col1, #T_9de09_row14_col2, #T_9de09_row14_col3, #T_9de09_row14_col4, #T_9de09_row14_col5, #T_9de09_row14_col6, #T_9de09_row15_col0, #T_9de09_row15_col1, #T_9de09_row15_col2, #T_9de09_row15_col3, #T_9de09_row15_col4, #T_9de09_row15_col5, #T_9de09_row15_col6, #T_9de09_row16_col0, #T_9de09_row16_col1, #T_9de09_row16_col2, #T_9de09_row16_col3, #T_9de09_row16_col4, #T_9de09_row16_col5, #T_9de09_row16_col6, #T_9de09_row17_col0, #T_9de09_row17_col1, #T_9de09_row17_col2, #T_9de09_row17_col3, #T_9de09_row17_col4, #T_9de09_row17_col5, #T_9de09_row17_col6, #T_9de09_row18_col0, #T_9de09_row18_col1, #T_9de09_row18_col2, #T_9de09_row18_col3, #T_9de09_row18_col4, #T_9de09_row18_col5, #T_9de09_row18_col6, #T_9de09_row19_col0, #T_9de09_row19_col1, #T_9de09_row19_col2, #T_9de09_row19_col3, #T_9de09_row19_col4, #T_9de09_row19_col5, #T_9de09_row19_col6 {
#   text-align: left;
# }
# #T_9de09_row0_col1, #T_9de09_row0_col2, #T_9de09_row0_col3, #T_9de09_row0_col4, #T_9de09_row3_col5, #T_9de09_row3_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_9de09_row0_col7, #T_9de09_row1_col7, #T_9de09_row2_col7, #T_9de09_row3_col7, #T_9de09_row4_col7, #T_9de09_row5_col7, #T_9de09_row6_col7, #T_9de09_row7_col7, #T_9de09_row8_col7, #T_9de09_row9_col7, #T_9de09_row10_col7, #T_9de09_row11_col7, #T_9de09_row12_col7, #T_9de09_row13_col7, #T_9de09_row14_col7, #T_9de09_row15_col7, #T_9de09_row17_col7, #T_9de09_row18_col7, #T_9de09_row19_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_9de09_row16_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_9de09">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9de09_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_9de09_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_9de09_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_9de09_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_9de09_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_9de09_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_9de09_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_9de09_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9de09_level0_row0" class="row_heading level0 row0" >catboost</th>
#       <td id="T_9de09_row0_col0" class="data row0 col0" >CatBoost Regressor</td>
#       <td id="T_9de09_row0_col1" class="data row0 col1" >15.3755</td>
#       <td id="T_9de09_row0_col2" class="data row0 col2" >420.9202</td>
#       <td id="T_9de09_row0_col3" class="data row0 col3" >20.4987</td>
#       <td id="T_9de09_row0_col4" class="data row0 col4" >0.1051</td>
#       <td id="T_9de09_row0_col5" class="data row0 col5" >1.0892</td>
#       <td id="T_9de09_row0_col6" class="data row0 col6" >2.7488</td>
#       <td id="T_9de09_row0_col7" class="data row0 col7" >1.4170</td>
#     </tr>
#     <tr>
#       <th id="T_9de09_level0_row1" class="row_heading level0 row1" >gbr</th>
#       <td id="T_9de09_row1_col0" class="data row1 col0" >Gradient Boosting Regressor</td>
#       <td id="T_9de09_row1_col1" class="data row1 col1" >15.6534</td>
#       <td id="T_9de09_row1_col2" class="data row1 col2" >428.9732</td>
#       <td id="T_9de09_row1_col3" class="data row1 col3" >20.7009</td>
#       <td id="T_9de09_row1_col4" class="data row1 col4" >0.0879</td>
#       <td id="T_9de09_row1_col5" class="data row1 col5" >1.1125</td>
#       <td id="T_9de09_row1_col6" class="data row1 col6" >2.9203</td>
#       <td id="T_9de09_row1_col7" class="data row1 col7" >0.7630</td>
#     </tr>
#     <tr>
#       <th id="T_9de09_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_9de09_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_9de09_row2_col1" class="data row2 col1" >15.6395</td>
#       <td id="T_9de09_row2_col2" class="data row2 col2" >435.4154</td>
#       <td id="T_9de09_row2_col3" class="data row2 col3" >20.8572</td>
#       <td id="T_9de09_row2_col4" class="data row2 col4" >0.0733</td>
#       <td id="T_9de09_row2_col5" class="data row2 col5" >1.0988</td>
#       <td id="T_9de09_row2_col6" class="data row2 col6" >2.7988</td>
#       <td id="T_9de09_row2_col7" class="data row2 col7" >0.8780</td>
#     </tr>
#     <tr>
#       <th id="T_9de09_level0_row3" class="row_heading level0 row3" >xgboost</th>
#       <td id="T_9de09_row3_col0" class="data row3 col0" >Extreme Gradient Boosting</td>
#       <td id="T_9de09_row3_col1" class="data row3 col1" >15.5539</td>
#       <td id="T_9de09_row3_col2" class="data row3 col2" >442.3036</td>
#       <td id="T_9de09_row3_col3" class="data row3 col3" >21.0151</td>
#       <td id="T_9de09_row3_col4" class="data row3 col4" >0.0586</td>
#       <td id="T_9de09_row3_col5" class="data row3 col5" >1.0736</td>
#       <td id="T_9de09_row3_col6" class="data row3 col6" >2.5591</td>
#       <td id="T_9de09_row3_col7" class="data row3 col7" >0.8120</td>
#     </tr>
#     <tr>
#       <th id="T_9de09_level0_row4" class="row_heading level0 row4" >lasso</th>
#       <td id="T_9de09_row4_col0" class="data row4 col0" >Lasso Regression</td>
#       <td id="T_9de09_row4_col1" class="data row4 col1" >16.6240</td>
#       <td id="T_9de09_row4_col2" class="data row4 col2" >471.1155</td>
#       <td id="T_9de09_row4_col3" class="data row4 col3" >21.6943</td>
#       <td id="T_9de09_row4_col4" class="data row4 col4" >-0.0015</td>
#       <td id="T_9de09_row4_col5" class="data row4 col5" >1.1581</td>
#       <td id="T_9de09_row4_col6" class="data row4 col6" >3.1447</td>
#       <td id="T_9de09_row4_col7" class="data row4 col7" >0.8780</td>
#     </tr>
#     <tr>
#       <th id="T_9de09_level0_row5" class="row_heading level0 row5" >ridge</th>
#       <td id="T_9de09_row5_col0" class="data row5 col0" >Ridge Regression</td>
#       <td id="T_9de09_row5_col1" class="data row5 col1" >16.6249</td>
#       <td id="T_9de09_row5_col2" class="data row5 col2" >471.1157</td>
#       <td id="T_9de09_row5_c
# <style type="text/css">
# #T_bce11 th {
#   text-align: left;
# }
# #T_bce11_row0_col0, #T_bce11_row0_col5, #T_bce11_row0_col6, #T_bce11_row1_col0, #T_bce11_row1_col1, #T_bce11_row1_col2, #T_bce11_row1_col3, #T_bce11_row1_col4, #T_bce11_row1_col5, #T_bce11_row1_col6, #T_bce11_row2_col0, #T_bce11_row2_col1, #T_bce11_row2_col2, #T_bce11_row2_col3, #T_bce11_row2_col4, #T_bce11_row2_col5, #T_bce11_row2_col6, #T_bce11_row3_col0, #T_bce11_row3_col1, #T_bce11_row3_col2, #T_bce11_row3_col3, #T_bce11_row3_col4, #T_bce11_row4_col0, #T_bce11_row4_col1, #T_bce11_row4_col2, #T_bce11_row4_col3, #T_bce11_row4_col4, #T_bce11_row4_col5, #T_bce11_row4_col6, #T_bce11_row5_col0, #T_bce11_row5_col1, #T_bce11_row5_col2, #T_bce11_row5_col3, #T_bce11_row5_col4, #T_bce11_row5_col5, #T_bce11_row5_col6, #T_bce11_row6_col0, #T_bce11_row6_col1, #T_bce11_row6_col2, #T_bce11_row6_col3, #T_bce11_row6_col4, #T_bce11_row6_col5, #T_bce11_row6_col6, #T_bce11_row7_col0, #T_bce11_row7_col1, #T_bce11_row7_col2, #T_bce11_row7_col3, #T_bce11_row7_col4, #T_bce11_row7_col5, #T_bce11_row7_col6, #T_bce11_row8_col0, #T_bce11_row8_col1, #T_bce11_row8_col2, #T_bce11_row8_col3, #T_bce11_row8_col4, #T_bce11_row8_col5, #T_bce11_row8_col6, #T_bce11_row9_col0, #T_bce11_row9_col1, #T_bce11_row9_col2, #T_bce11_row9_col3, #T_bce11_row9_col4, #T_bce11_row9_col5, #T_bce11_row9_col6, #T_bce11_row10_col0, #T_bce11_row10_col1, #T_bce11_row10_col2, #T_bce11_row10_col3, #T_bce11_row10_col4, #T_bce11_row10_col5, #T_bce11_row10_col6, #T_bce11_row11_col0, #T_bce11_row11_col1, #T_bce11_row11_col2, #T_bce11_row11_col3, #T_bce11_row11_col4, #T_bce11_row11_col5, #T_bce11_row11_col6, #T_bce11_row12_col0, #T_bce11_row12_col1, #T_bce11_row12_col2, #T_bce11_row12_col3, #T_bce11_row12_col4, #T_bce11_row12_col5, #T_bce11_row12_col6, #T_bce11_row13_col0, #T_bce11_row13_col1, #T_bce11_row13_col2, #T_bce11_row13_col3, #T_bce11_row13_col4, #T_bce11_row13_col5, #T_bce11_row13_col6, #T_bce11_row14_col0, #T_bce11_row14_col1, #T_bce11_row14_col2, #T_bce11_row14_col3, #T_bce11_row14_col4, #T_bce11_row14_col5, #T_bce11_row14_col6, #T_bce11_row15_col0, #T_bce11_row15_col1, #T_bce11_row15_col2, #T_bce11_row15_col3, #T_bce11_row15_col4, #T_bce11_row15_col5, #T_bce11_row15_col6, #T_bce11_row16_col0, #T_bce11_row16_col1, #T_bce11_row16_col2, #T_bce11_row16_col3, #T_bce11_row16_col4, #T_bce11_row16_col5, #T_bce11_row16_col6, #T_bce11_row17_col0, #T_bce11_row17_col1, #T_bce11_row17_col2, #T_bce11_row17_col3, #T_bce11_row17_col4, #T_bce11_row17_col5, #T_bce11_row17_col6, #T_bce11_row18_col0, #T_bce11_row18_col1, #T_bce11_row18_col2, #T_bce11_row18_col3, #T_bce11_row18_col4, #T_bce11_row18_col5, #T_bce11_row18_col6, #T_bce11_row19_col0, #T_bce11_row19_col1, #T_bce11_row19_col2, #T_bce11_row19_col3, #T_bce11_row19_col4, #T_bce11_row19_col5, #T_bce11_row19_col6 {
#   text-align: left;
# }
# #T_bce11_row0_col1, #T_bce11_row0_col2, #T_bce11_row0_col3, #T_bce11_row0_col4, #T_bce11_row3_col5, #T_bce11_row3_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_bce11_row0_col7, #T_bce11_row1_col7, #T_bce11_row2_col7, #T_bce11_row3_col7, #T_bce11_row4_col7, #T_bce11_row5_col7, #T_bce11_row6_col7, #T_bce11_row7_col7, #T_bce11_row8_col7, #T_bce11_row9_col7, #T_bce11_row10_col7, #T_bce11_row11_col7, #T_bce11_row12_col7, #T_bce11_row13_col7, #T_bce11_row14_col7, #T_bce11_row15_col7, #T_bce11_row16_col7, #T_bce11_row17_col7, #T_bce11_row18_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_bce11_row19_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_bce11">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bce11_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_bce11_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_bce11_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_bce11_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_bce11_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_bce11_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_bce11_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_bce11_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bce11_level0_row0" class="row_heading level0 row0" >catboost</th>
#       <td id="T_bce11_row0_col0" class="data row0 col0" >CatBoost Regressor</td>
#       <td id="T_bce11_row0_col1" class="data row0 col1" >15.4423</td>
#       <td id="T_bce11_row0_col2" class="data row0 col2" >420.7987</td>
#       <td id="T_bce11_row0_col3" class="data row0 col3" >20.5072</td>
#       <td id="T_bce11_row0_col4" class="data row0 col4" >0.1065</td>
#       <td id="T_bce11_row0_col5" class="data row0 col5" >1.0927</td>
#       <td id="T_bce11_row0_col6" class="data row0 col6" >2.7637</td>
#       <td id="T_bce11_row0_col7" class="data row0 col7" >1.4620</td>
#     </tr>
#     <tr>
#       <th id="T_bce11_level0_row1" class="row_heading level0 row1" >gbr</th>
#       <td id="T_bce11_row1_col0" class="data row1 col0" >Gradient Boosting Regressor</td>
#       <td id="T_bce11_row1_col1" class="data row1 col1" >15.7083</td>
#       <td id="T_bce11_row1_col2" class="data row1 col2" >431.0744</td>
#       <td id="T_bce11_row1_col3" class="data row1 col3" >20.7585</td>
#       <td id="T_bce11_row1_col4" class="data row1 col4" >0.0843</td>
#       <td id="T_bce11_row1_col5" class="data row1 col5" >1.1164</td>
#       <td id="T_bce11_row1_col6" class="data row1 col6" >2.9410</td>
#       <td id="T_bce11_row1_col7" class="data row1 col7" >0.8420</td>
#     </tr>
#     <tr>
#       <th id="T_bce11_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_bce11_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_bce11_row2_col1" class="data row2 col1" >15.7092</td>
#       <td id="T_bce11_row2_col2" class="data row2 col2" >437.0106</td>
#       <td id="T_bce11_row2_col3" class="data row2 col3" >20.8995</td>
#       <td id="T_bce11_row2_col4" class="data row2 col4" >0.0719</td>
#       <td id="T_bce11_row2_col5" class="data row2 col5" >1.1010</td>
#       <td id="T_bce11_row2_col6" class="data row2 col6" >2.7951</td>
#       <td id="T_bce11_row2_col7" class="data row2 col7" >1.0660</td>
#     </tr>
#     <tr>
#       <th id="T_bce11_level0_row3" class="row_heading level0 row3" >xgboost</th>
#       <td id="T_bce11_row3_col0" class="data row3 col0" >Extreme Gradient Boosting</td>
#       <td id="T_bce11_row3_col1" class="data row3 col1" >15.6844</td>
#       <td id="T_bce11_row3_col2" class="data row3 col2" >447.7629</td>
#       <td id="T_bce11_row3_col3" class="data row3 col3" >21.1543</td>
#       <td id="T_bce11_row3_col4" class="data row3 col4" >0.0491</td>
#       <td id="T_bce11_row3_col5" class="data row3 col5" >1.0858</td>
#       <td id="T_bce11_row3_col6" class="data row3 col6" >2.6101</td>
#       <td id="T_bce11_row3_col7" class="data row3 col7" >1.0780</td>
#     </tr>
#     <tr>
#       <th id="T_bce11_level0_row4" class="row_heading level0 row4" >dummy</th>
#       <td id="T_bce11_row4_col0" class="data row4 col0" >Dummy Regressor</td>
#       <td id="T_bce11_row4_col1" class="data row4 col1" >16.6129</td>
#       <td id="T_bce11_row4_col2" class="data row4 col2" >471.2513</td>
#       <td id="T_bce11_row4_col3" class="data row4 col3" >21.7047</td>
#       <td id="T_bce11_row4_col4" class="data row4 col4" >-0.0011</td>
#       <td id="T_bce11_row4_col5" class="data row4 col5" >1.1589</td>
#       <td id="T_bce11_row4_col6" class="data row4 col6" >3.1478</td>
#       <td id="T_bce11_row4_col7" class="data row4 col7" >0.9220</td>
#     </tr>
#     <tr>
#       <th id="T_bce11_level0_row5" class="row_heading level0 row5" >omp</th>
#       <td id="T_bce11_row5_col0" class="data row5 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_bce11_row5_col1" class="data row5 col1" >16.6259</td>
#       <td id="T_bce11_row5_col2" class="data row5 col2" >471.5490</td>
#       <td id="T_bce1

# %%
# Create the Catboost Regressor model for the batsman dataset using the top-performing model's hyperparameters
batsman_catboost_model = create_model('catboost', fold=5)

# Save the trained Catboost Regressor model for the batsman dataset to a file
save_model(batsman_catboost_model, 'batsman_Catboost_Regressor_model')
# Out:
# <style type="text/css">
# #T_fdde0_row5_col0, #T_fdde0_row5_col1, #T_fdde0_row5_col2, #T_fdde0_row5_col3, #T_fdde0_row5_col4, #T_fdde0_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_fdde0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fdde0_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_fdde0_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_fdde0_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_fdde0_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_fdde0_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_fdde0_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fdde0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fdde0_row0_col0" class="data row0 col0" >15.8975</td>
#       <td id="T_fdde0_row0_col1" class="data row0 col1" >446.8980</td>
#       <td id="T_fdde0_row0_col2" class="data row0 col2" >21.1400</td>
#       <td id="T_fdde0_row0_col3" class="data row0 col3" >0.0804</td>
#       <td id="T_fdde0_row0_col4" class="data row0 col4" >1.1281</td>
#       <td id="T_fdde0_row0_col5" class="data row0 col5" >2.7689</td>
#     </tr>
#     <tr>
#       <th id="T_fdde0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fdde0_row1_col0" class="data row1 col0" >15.7521</td>
#       <td id="T_fdde0_row1_col1" class="data row1 col1" >421.0243</td>
#       <td id="T_fdde0_row1_col2" class="data row1 col2" >20.5189</td>
#       <td id="T_fdde0_row1_col3" class="data row1 col3" >0.1142</td>
#       <td id="T_fdde0_row1_col4" class="data row1 col4" >1.0861</td>
#       <td id="T_fdde0_row1_col5" class="data row1 col5" >2.7384</td>
#     </tr>
#     <tr>
#       <th id="T_fdde0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fdde0_row2_col0" class="data row2 col0" >15.2367</td>
#       <td id="T_fdde0_row2_col1" class="data row2 col1" >402.9362</td>
#       <td id="T_fdde0_row2_col2" class="data row2 col2" >20.0733</td>
#       <td id="T_fdde0_row2_col3" class="data row2 col3" >0.1154</td>
#       <td id="T_fdde0_row2_col4" class="data row2 col4" >1.0999</td>
#       <td id="T_fdde0_row2_col5" class="data row2 col5" >2.9449</td>
#     </tr>
#     <tr>
#       <th id="T_fdde0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_fdde0_row3_col0" class="data row3 col0" >15.0678</td>
#       <td id="T_fdde0_row3_col1" class="data row3 col1" >393.2204</td>
#       <td id="T_fdde0_row3_col2" class="data row3 col2" >19.8298</td>
#       <td id="T_fdde0_row3_col3" class="data row3 col3" >0.1180</td>
#       <td id="T_fdde0_row3_col4" class="data row3 col4" >1.1211</td>
#       <td id="T_fdde0_row3_col5" class="data row3 col5" >3.0529</td>
#     </tr>
#     <tr>
#       <th id="T_fdde0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_fdde0_row4_col0" class="data row4 col0" >15.2573</td>
#       <td id="T_fdde0_row4_col1" class="data row4 col1" >439.9148</td>
#       <td id="T_fdde0_row4_col2" class="data row4 col2" >20.9741</td>
#       <td id="T_fdde0_row4_col3" class="data row4 col3" >0.1043</td>
#       <td id="T_fdde0_row4_col4" class="data row4 col4" >1.0285</td>
#       <td id="T_fdde0_row4_col5" class="data row4 col5" >2.3136</td>
#     </tr>
#     <tr>
#       <th id="T_fdde0_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_fdde0_row5_col0" class="data row5 col0" >15.4423</td>
#       <td id="T_fdde0_row5_col1" class="data row5 col1" >420.7987</td>
#       <td id="T_fdde0_row5_col2" class="data row5 col2" >20.5072</td>
#       <td id="T_fdde0_row5_col3" class="data row5 col3" >0.1065</td>
#       <td id="T_fdde0_row5_col4" class="data row5 col4" >1.0927</td>
#       <td id="T_fdde0_row5_col5" class="data row5 col5" >2.7637</td>
#     </tr>
#     <tr>
#       <th id="T_fdde0_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_fdde0_row6_col0" class="data row6 col0" >0.3225</td>
#       <td id="T_fdde0_row6_col1" class="data row6 col1" >20.6218</td>
#       <td id="T_fdde0_row6_col2" class="data row6 col2" >0.5031</td>
#       <td id="T_fdde0_row6_col3" class="data row6 col3" >0.0139</td>
#       <td id="T_fdde0_row6_col4" class="data row6 col4" >0.0354</td>
#       <td id="T_fdde0_row6_col5" class="data row6 col5" >0.2529</td>
#     </tr>
#   </tbody>
# </table>
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=FastMemory(location=C:\Users\harsh\AppData\Local\Temp\joblib),
#           steps=[('placeholder', None),
#                  ('trained_model',
#                   <catboost.core.CatBoostRegressor object at 0x000001F5F379F910>)]),
#  'batsman_Catboost_Regressor_model.pkl')

# %%
# Set up the PyCaret environment for the batsman dataset
# Make sure to replace 'target' with the name of the target column (the one you want to predict)
bowler_regression_setup = setup(
    data=venue_grouped_bowler, target='d11', train_size=0.7, verbose=False, preprocess=False
)
# Compare all models and print the results for the batsman dataset
best_bowler_model = compare_models(fold = 5, round = 4, sort = 'R2', turbo = True, verbose=True)
# Out:
# <style type="text/css">
# #T_3d780 th {
#   text-align: left;
# }
# #T_3d780_row0_col0, #T_3d780_row0_col5, #T_3d780_row1_col0, #T_3d780_row1_col1, #T_3d780_row1_col2, #T_3d780_row1_col3, #T_3d780_row1_col4, #T_3d780_row1_col5, #T_3d780_row1_col6, #T_3d780_row2_col0, #T_3d780_row2_col1, #T_3d780_row2_col2, #T_3d780_row2_col3, #T_3d780_row2_col4, #T_3d780_row2_col5, #T_3d780_row2_col6, #T_3d780_row3_col0, #T_3d780_row3_col1, #T_3d780_row3_col2, #T_3d780_row3_col3, #T_3d780_row3_col4, #T_3d780_row3_col5, #T_3d780_row3_col6, #T_3d780_row4_col0, #T_3d780_row4_col1, #T_3d780_row4_col2, #T_3d780_row4_col3, #T_3d780_row4_col4, #T_3d780_row4_col5, #T_3d780_row4_col6, #T_3d780_row5_col0, #T_3d780_row5_col1, #T_3d780_row5_col2, #T_3d780_row5_col3, #T_3d780_row5_col4, #T_3d780_row5_col5, #T_3d780_row5_col6, #T_3d780_row6_col0, #T_3d780_row6_col1, #T_3d780_row6_col2, #T_3d780_row6_col3, #T_3d780_row6_col4, #T_3d780_row6_col5, #T_3d780_row6_col6, #T_3d780_row7_col0, #T_3d780_row7_col1, #T_3d780_row7_col2, #T_3d780_row7_col3, #T_3d780_row7_col4, #T_3d780_row7_col5, #T_3d780_row7_col6, #T_3d780_row8_col0, #T_3d780_row8_col1, #T_3d780_row8_col2, #T_3d780_row8_col3, #T_3d780_row8_col4, #T_3d780_row8_col5, #T_3d780_row8_col6, #T_3d780_row9_col0, #T_3d780_row9_col1, #T_3d780_row9_col2, #T_3d780_row9_col3, #T_3d780_row9_col4, #T_3d780_row9_col5, #T_3d780_row9_col6, #T_3d780_row10_col0, #T_3d780_row10_col1, #T_3d780_row10_col2, #T_3d780_row10_col3, #T_3d780_row10_col4, #T_3d780_row10_col5, #T_3d780_row10_col6, #T_3d780_row11_col0, #T_3d780_row11_col1, #T_3d780_row11_col2, #T_3d780_row11_col3, #T_3d780_row11_col4, #T_3d780_row11_col5, #T_3d780_row11_col6, #T_3d780_row12_col0, #T_3d780_row12_col1, #T_3d780_row12_col2, #T_3d780_row12_col3, #T_3d780_row12_col4, #T_3d780_row12_col5, #T_3d780_row12_col6, #T_3d780_row13_col0, #T_3d780_row13_col1, #T_3d780_row13_col2, #T_3d780_row13_col3, #T_3d780_row13_col4, #T_3d780_row13_col6, #T_3d780_row14_col0, #T_3d780_row14_col1, #T_3d780_row14_col2, #T_3d780_row14_col3, #T_3d780_row14_col4, #T_3d780_row14_col5, #T_3d780_row14_col6, #T_3d780_row15_col0, #T_3d780_row15_col1, #T_3d780_row15_col2, #T_3d780_row15_col3, #T_3d780_row15_col4, #T_3d780_row15_col5, #T_3d780_row15_col6, #T_3d780_row16_col0, #T_3d780_row16_col1, #T_3d780_row16_col2, #T_3d780_row16_col3, #T_3d780_row16_col4, #T_3d780_row16_col5, #T_3d780_row16_col6, #T_3d780_row17_col0, #T_3d780_row17_col1, #T_3d780_row17_col2, #T_3d780_row17_col3, #T_3d780_row17_col4, #T_3d780_row17_col5, #T_3d780_row17_col6, #T_3d780_row18_col0, #T_3d780_row18_col1, #T_3d780_row18_col2, #T_3d780_row18_col3, #T_3d780_row18_col4, #T_3d780_row18_col5, #T_3d780_row18_col6, #T_3d780_row19_col0, #T_3d780_row19_col1, #T_3d780_row19_col2, #T_3d780_row19_col3, #T_3d780_row19_col4, #T_3d780_row19_col5, #T_3d780_row19_col6 {
#   text-align: left;
# }
# #T_3d780_row0_col1, #T_3d780_row0_col2, #T_3d780_row0_col3, #T_3d780_row0_col4, #T_3d780_row0_col6, #T_3d780_row13_col5 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_3d780_row0_col7, #T_3d780_row1_col7, #T_3d780_row2_col7, #T_3d780_row3_col7, #T_3d780_row4_col7, #T_3d780_row5_col7, #T_3d780_row6_col7, #T_3d780_row7_col7, #T_3d780_row8_col7, #T_3d780_row9_col7, #T_3d780_row10_col7, #T_3d780_row11_col7, #T_3d780_row12_col7, #T_3d780_row13_col7, #T_3d780_row14_col7, #T_3d780_row15_col7, #T_3d780_row16_col7, #T_3d780_row17_col7, #T_3d780_row18_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_3d780_row19_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_3d780">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3d780_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_3d780_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_3d780_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_3d780_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_3d780_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_3d780_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_3d780_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_3d780_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3d780_level0_row0" class="row_heading level0 row0" >gbr</th>
#       <td id="T_3d780_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_3d780_row0_col1" class="data row0 col1" >9.5685</td>
#       <td id="T_3d780_row0_col2" class="data row0 col2" >119.2744</td>
#       <td id="T_3d780_row0_col3" class="data row0 col3" >10.9124</td>
#       <td id="T_3d780_row0_col4" class="data row0 col4" >-0.0026</td>
#       <td id="T_3d780_row0_col5" class="data row0 col5" >1.4928</td>
#       <td id="T_3d780_row0_col6" class="data row0 col6" >0.3724</td>
#       <td id="T_3d780_row0_col7" class="data row0 col7" >0.7520</td>
#     </tr>
#     <tr>
#       <th id="T_3d780_level0_row1" class="row_heading level0 row1" >omp</th>
#       <td id="T_3d780_row1_col0" class="data row1 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_3d780_row1_col1" class="data row1 col1" >9.6736</td>
#       <td id="T_3d780_row1_col2" class="data row1 col2" >119.6986</td>
#       <td id="T_3d780_row1_col3" class="data row1 col3" >10.9334</td>
#       <td id="T_3d780_row1_col4" class="data row1 col4" >-0.0065</td>
#       <td id="T_3d780_row1_col5" class="data row1 col5" >1.5012</td>
#       <td id="T_3d780_row1_col6" class="data row1 col6" >0.3751</td>
#       <td id="T_3d780_row1_col7" class="data row1 col7" >0.6290</td>
#     </tr>
#     <tr>
#       <th id="T_3d780_level0_row2" class="row_heading level0 row2" >br</th>
#       <td id="T_3d780_row2_col0" class="data row2 col0" >Bayesian Ridge</td>
#       <td id="T_3d780_row2_col1" class="data row2 col1" >9.6746</td>
#       <td id="T_3d780_row2_col2" class="data row2 col2" >119.7099</td>
#       <td id="T_3d780_row2_col3" class="data row2 col3" >10.9341</td>
#       <td id="T_3d780_row2_col4" class="data row2 col4" >-0.0067</td>
#       <td id="T_3d780_row2_col5" class="data row2 col5" >1.5013</td>
#       <td id="T_3d780_row2_col6" class="data row2 col6" >0.3751</td>
#       <td id="T_3d780_row2_col7" class="data row2 col7" >0.5760</td>
#     </tr>
#     <tr>
#       <th id="T_3d780_level0_row3" class="row_heading level0 row3" >lasso</th>
#       <td id="T_3d780_row3_col0" class="data row3 col0" >Lasso Regression</td>
#       <td id="T_3d780_row3_col1" class="data row3 col1" >9.6748</td>
#       <td id="T_3d780_row3_col2" class="data row3 col2" >119.7267</td>
#       <td id="T_3d780_row3_col3" class="data row3 col3" >10.9347</td>
#       <td id="T_3d780_row3_col4" class="data row3 col4" >-0.0068</td>
#       <td id="T_3d780_row3_col5" class="data row3 col5" >1.5013</td>
#       <td id="T_3d780_row3_col6" class="data row3 col6" >0.3752</td>
#       <td id="T_3d780_row3_col7" class="data row3 col7" >0.8050</td>
#     </tr>
#     <tr>
#       <th id="T_3d780_level0_row4" class="row_heading level0 row4" >llar</th>
#       <td id="T_3d780_row4_col0" class="data row4 col0" >Lasso Least Angle Regression</td>
#       <td id="T_3d780_row4_col1" class="data row4 col1" >9.6748</td>
#       <td id="T_3d780_row4_col2" class="data row4 col2" >119.7267</td>
#       <td id="T_3d780_row4_col3" class="data row4 col3" >10.9347</td>
#       <td id="T_3d780_row4_col4" class="data row4 col4" >-0.0068</td>
#       <td id="T_3d780_row4_col5" class="data row4 col5" >1.5013</td>
#       <td id="T_3d780_row4_col6" class="data row4 col6" >0.3752</td>
#       <td id="T_3d780_row4_col7" class="data row4 col7" >0.6420</td>
#     </tr>
#     <tr>
#       <th id="T_3d780_level0_row5" class="row_heading level0 row5" >en</th>
#       <td id="T_3d780_row5_col0" class="data row5 col0" >Elastic Net</td>
#       <td id="T_3d780_row5_col1" class="data row5 col1" >9.6757</td>
#       <td id="T_3d780_row5_col2" class="data row5 col2" >119.7495</td>
#       <td id="T_3d780_row5_col3" class="data row5 col3" >
# <style type="text/css">
# #T_a073e th {
#   text-align: left;
# }
# #T_a073e_row0_col0, #T_a073e_row0_col5, #T_a073e_row1_col0, #T_a073e_row1_col1, #T_a073e_row1_col2, #T_a073e_row1_col3, #T_a073e_row1_col4, #T_a073e_row1_col6, #T_a073e_row2_col0, #T_a073e_row2_col1, #T_a073e_row2_col2, #T_a073e_row2_col3, #T_a073e_row2_col4, #T_a073e_row2_col5, #T_a073e_row2_col6, #T_a073e_row3_col0, #T_a073e_row3_col1, #T_a073e_row3_col2, #T_a073e_row3_col3, #T_a073e_row3_col4, #T_a073e_row3_col5, #T_a073e_row3_col6, #T_a073e_row4_col0, #T_a073e_row4_col1, #T_a073e_row4_col2, #T_a073e_row4_col3, #T_a073e_row4_col4, #T_a073e_row4_col5, #T_a073e_row4_col6, #T_a073e_row5_col0, #T_a073e_row5_col1, #T_a073e_row5_col2, #T_a073e_row5_col3, #T_a073e_row5_col4, #T_a073e_row5_col5, #T_a073e_row5_col6, #T_a073e_row6_col0, #T_a073e_row6_col1, #T_a073e_row6_col2, #T_a073e_row6_col3, #T_a073e_row6_col4, #T_a073e_row6_col5, #T_a073e_row6_col6, #T_a073e_row7_col0, #T_a073e_row7_col1, #T_a073e_row7_col2, #T_a073e_row7_col3, #T_a073e_row7_col4, #T_a073e_row7_col5, #T_a073e_row7_col6, #T_a073e_row8_col0, #T_a073e_row8_col1, #T_a073e_row8_col2, #T_a073e_row8_col3, #T_a073e_row8_col4, #T_a073e_row8_col5, #T_a073e_row8_col6, #T_a073e_row9_col0, #T_a073e_row9_col1, #T_a073e_row9_col2, #T_a073e_row9_col3, #T_a073e_row9_col4, #T_a073e_row9_col5, #T_a073e_row9_col6, #T_a073e_row10_col0, #T_a073e_row10_col1, #T_a073e_row10_col2, #T_a073e_row10_col3, #T_a073e_row10_col4, #T_a073e_row10_col5, #T_a073e_row10_col6, #T_a073e_row11_col0, #T_a073e_row11_col1, #T_a073e_row11_col2, #T_a073e_row11_col3, #T_a073e_row11_col4, #T_a073e_row11_col5, #T_a073e_row11_col6, #T_a073e_row12_col0, #T_a073e_row12_col1, #T_a073e_row12_col2, #T_a073e_row12_col3, #T_a073e_row12_col4, #T_a073e_row12_col5, #T_a073e_row12_col6, #T_a073e_row13_col0, #T_a073e_row13_col1, #T_a073e_row13_col2, #T_a073e_row13_col3, #T_a073e_row13_col4, #T_a073e_row13_col5, #T_a073e_row13_col6, #T_a073e_row14_col0, #T_a073e_row14_col1, #T_a073e_row14_col2, #T_a073e_row14_col3, #T_a073e_row14_col4, #T_a073e_row14_col5, #T_a073e_row14_col6, #T_a073e_row15_col0, #T_a073e_row15_col1, #T_a073e_row15_col2, #T_a073e_row15_col3, #T_a073e_row15_col4, #T_a073e_row15_col5, #T_a073e_row15_col6, #T_a073e_row16_col0, #T_a073e_row16_col1, #T_a073e_row16_col2, #T_a073e_row16_col3, #T_a073e_row16_col4, #T_a073e_row16_col5, #T_a073e_row16_col6, #T_a073e_row17_col0, #T_a073e_row17_col1, #T_a073e_row17_col2, #T_a073e_row17_col3, #T_a073e_row17_col4, #T_a073e_row17_col5, #T_a073e_row17_col6, #T_a073e_row18_col0, #T_a073e_row18_col1, #T_a073e_row18_col2, #T_a073e_row18_col3, #T_a073e_row18_col4, #T_a073e_row18_col5, #T_a073e_row18_col6, #T_a073e_row19_col0, #T_a073e_row19_col1, #T_a073e_row19_col2, #T_a073e_row19_col3, #T_a073e_row19_col4, #T_a073e_row19_col5, #T_a073e_row19_col6 {
#   text-align: left;
# }
# #T_a073e_row0_col1, #T_a073e_row0_col2, #T_a073e_row0_col3, #T_a073e_row0_col4, #T_a073e_row0_col6, #T_a073e_row1_col5 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_a073e_row0_col7, #T_a073e_row1_col7, #T_a073e_row2_col7, #T_a073e_row3_col7, #T_a073e_row4_col7, #T_a073e_row5_col7, #T_a073e_row6_col7, #T_a073e_row7_col7, #T_a073e_row8_col7, #T_a073e_row9_col7, #T_a073e_row10_col7, #T_a073e_row11_col7, #T_a073e_row12_col7, #T_a073e_row13_col7, #T_a073e_row14_col7, #T_a073e_row15_col7, #T_a073e_row16_col7, #T_a073e_row17_col7, #T_a073e_row18_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_a073e_row19_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_a073e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a073e_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_a073e_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_a073e_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_a073e_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_a073e_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_a073e_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_a073e_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_a073e_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a073e_level0_row0" class="row_heading level0 row0" >gbr</th>
#       <td id="T_a073e_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_a073e_row0_col1" class="data row0 col1" >9.5536</td>
#       <td id="T_a073e_row0_col2" class="data row0 col2" >119.3707</td>
#       <td id="T_a073e_row0_col3" class="data row0 col3" >10.9187</td>
#       <td id="T_a073e_row0_col4" class="data row0 col4" >0.0015</td>
#       <td id="T_a073e_row0_col5" class="data row0 col5" >1.4943</td>
#       <td id="T_a073e_row0_col6" class="data row0 col6" >0.3720</td>
#       <td id="T_a073e_row0_col7" class="data row0 col7" >0.6720</td>
#     </tr>
#     <tr>
#       <th id="T_a073e_level0_row1" class="row_heading level0 row1" >ada</th>
#       <td id="T_a073e_row1_col0" class="data row1 col0" >AdaBoost Regressor</td>
#       <td id="T_a073e_row1_col1" class="data row1 col1" >9.6786</td>
#       <td id="T_a073e_row1_col2" class="data row1 col2" >119.6489</td>
#       <td id="T_a073e_row1_col3" class="data row1 col3" >10.9325</td>
#       <td id="T_a073e_row1_col4" class="data row1 col4" >-0.0012</td>
#       <td id="T_a073e_row1_col5" class="data row1 col5" >1.4927</td>
#       <td id="T_a073e_row1_col6" class="data row1 col6" >0.3773</td>
#       <td id="T_a073e_row1_col7" class="data row1 col7" >0.7380</td>
#     </tr>
#     <tr>
#       <th id="T_a073e_level0_row2" class="row_heading level0 row2" >omp</th>
#       <td id="T_a073e_row2_col0" class="data row2 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_a073e_row2_col1" class="data row2 col1" >9.6728</td>
#       <td id="T_a073e_row2_col2" class="data row2 col2" >119.6773</td>
#       <td id="T_a073e_row2_col3" class="data row2 col3" >10.9339</td>
#       <td id="T_a073e_row2_col4" class="data row2 col4" >-0.0014</td>
#       <td id="T_a073e_row2_col5" class="data row2 col5" >1.5032</td>
#       <td id="T_a073e_row2_col6" class="data row2 col6" >0.3751</td>
#       <td id="T_a073e_row2_col7" class="data row2 col7" >0.5800</td>
#     </tr>
#     <tr>
#       <th id="T_a073e_level0_row3" class="row_heading level0 row3" >br</th>
#       <td id="T_a073e_row3_col0" class="data row3 col0" >Bayesian Ridge</td>
#       <td id="T_a073e_row3_col1" class="data row3 col1" >9.6737</td>
#       <td id="T_a073e_row3_col2" class="data row3 col2" >119.6842</td>
#       <td id="T_a073e_row3_col3" class="data row3 col3" >10.9344</td>
#       <td id="T_a073e_row3_col4" class="data row3 col4" >-0.0015</td>
#       <td id="T_a073e_row3_col5" class="data row3 col5" >1.5033</td>
#       <td id="T_a073e_row3_col6" class="data row3 col6" >0.3751</td>
#       <td id="T_a073e_row3_col7" class="data row3 col7" >0.5480</td>
#     </tr>
#     <tr>
#       <th id="T_a073e_level0_row4" class="row_heading level0 row4" >dummy</th>
#       <td id="T_a073e_row4_col0" class="data row4 col0" >Dummy Regressor</td>
#       <td id="T_a073e_row4_col1" class="data row4 col1" >9.6727</td>
#       <td id="T_a073e_row4_col2" class="data row4 col2" >119.6994</td>
#       <td id="T_a073e_row4_col3" class="data row4 col3" >10.9353</td>
#       <td id="T_a073e_row4_col4" class="data row4 col4" >-0.0017</td>
#       <td id="T_a073e_row4_col5" class="data row4 col5" >1.5034</td>
#       <td id="T_a073e_row4_col6" class="data row4 col6" >0.3749</td>
#       <td id="T_a073e_row4_col7" class="data row4 col7" >0.5740</td>
#     </tr>
#     <tr>
#       <th id="T_a073e_level0_row5" class="row_heading level0 row5" >llar</th>
#       <td id="T_a073e_row5_col0" class="data row5 col0" >Lasso Least Angle Regression</td>
#       <td id="T_a073e_row5_col1" class="data row5 col1" >9.6747</td>
#       <td id="T_a073e_row5_col2" class="data row5 col2" >119.7293</td>
#       <td id="T_a073e_row5_col3" class="data row5 c
# GradientBoostingRegressor(random_state=1800)

# %%
# Create the Gradient Boosting Regressor model for the bowler dataset using the top-performing model's hyperparameters
bowler_gbr_model = create_model('gbr', fold=5)

# Save the trained Gradient Boosting Regressor model for the bowler dataset to a file
save_model(bowler_gbr_model, 'bowler_Gradient_Boosting_Regressor_model')
# Out:
# <style type="text/css">
# #T_97344_row5_col0, #T_97344_row5_col1, #T_97344_row5_col2, #T_97344_row5_col3, #T_97344_row5_col4, #T_97344_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_97344">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_97344_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_97344_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_97344_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_97344_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_97344_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_97344_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_97344_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_97344_row0_col0" class="data row0 col0" >9.7505</td>
#       <td id="T_97344_row0_col1" class="data row0 col1" >121.9103</td>
#       <td id="T_97344_row0_col2" class="data row0 col2" >11.0413</td>
#       <td id="T_97344_row0_col3" class="data row0 col3" >0.0174</td>
#       <td id="T_97344_row0_col4" class="data row0 col4" >1.5218</td>
#       <td id="T_97344_row0_col5" class="data row0 col5" >0.3859</td>
#     </tr>
#     <tr>
#       <th id="T_97344_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_97344_row1_col0" class="data row1 col0" >9.9508</td>
#       <td id="T_97344_row1_col1" class="data row1 col1" >128.5907</td>
#       <td id="T_97344_row1_col2" class="data row1 col2" >11.3398</td>
#       <td id="T_97344_row1_col3" class="data row1 col3" >-0.0211</td>
#       <td id="T_97344_row1_col4" class="data row1 col4" >1.5936</td>
#       <td id="T_97344_row1_col5" class="data row1 col5" >0.3683</td>
#     </tr>
#     <tr>
#       <th id="T_97344_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_97344_row2_col0" class="data row2 col0" >9.4116</td>
#       <td id="T_97344_row2_col1" class="data row2 col1" >118.6515</td>
#       <td id="T_97344_row2_col2" class="data row2 col2" >10.8927</td>
#       <td id="T_97344_row2_col3" class="data row2 col3" >-0.0110</td>
#       <td id="T_97344_row2_col4" class="data row2 col4" >1.4851</td>
#       <td id="T_97344_row2_col5" class="data row2 col5" >0.3562</td>
#     </tr>
#     <tr>
#       <th id="T_97344_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_97344_row3_col0" class="data row3 col0" >9.8853</td>
#       <td id="T_97344_row3_col1" class="data row3 col1" >123.8007</td>
#       <td id="T_97344_row3_col2" class="data row3 col2" >11.1266</td>
#       <td id="T_97344_row3_col3" class="data row3 col3" >0.0025</td>
#       <td id="T_97344_row3_col4" class="data row3 col4" >1.5081</td>
#       <td id="T_97344_row3_col5" class="data row3 col5" >0.3795</td>
#     </tr>
#     <tr>
#       <th id="T_97344_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_97344_row4_col0" class="data row4 col0" >8.7700</td>
#       <td id="T_97344_row4_col1" class="data row4 col1" >103.9000</td>
#       <td id="T_97344_row4_col2" class="data row4 col2" >10.1931</td>
#       <td id="T_97344_row4_col3" class="data row4 col3" >0.0197</td>
#       <td id="T_97344_row4_col4" class="data row4 col4" >1.3629</td>
#       <td id="T_97344_row4_col5" class="data row4 col5" >0.3701</td>
#     </tr>
#     <tr>
#       <th id="T_97344_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_97344_row5_col0" class="data row5 col0" >9.5536</td>
#       <td id="T_97344_row5_col1" class="data row5 col1" >119.3707</td>
#       <td id="T_97344_row5_col2" class="data row5 col2" >10.9187</td>
#       <td id="T_97344_row5_col3" class="data row5 col3" >0.0015</td>
#       <td id="T_97344_row5_col4" class="data row5 col4" >1.4943</td>
#       <td id="T_97344_row5_col5" class="data row5 col5" >0.3720</td>
#     </tr>
#     <tr>
#       <th id="T_97344_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_97344_row6_col0" class="data row6 col0" >0.4338</td>
#       <td id="T_97344_row6_col1" class="data row6 col1" >8.3779</td>
#       <td id="T_97344_row6_col2" class="data row6 col2" >0.3906</td>
#       <td id="T_97344_row6_col3" class="data row6 col3" >0.0158</td>
#       <td id="T_97344_row6_col4" class="data row6 col4" >0.0751</td>
#       <td id="T_97344_row6_col5" class="data row6 col5" >0.0102</td>
#     </tr>
#   </tbody>
# </table>
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=FastMemory(location=C:\Users\harsh\AppData\Local\Temp\joblib),
#           steps=[('placeholder', None),
#                  ('trained_model',
#                   GradientBoostingRegressor(random_state=1800))]),
#  'bowler_Gradient_Boosting_Regressor_model.pkl')

# %%
# Split the datasets into train and test sets
train_batsman_df, test_batsman_df = train_test_split(
    venue_grouped_batsman, test_size=0.2, random_state=42
)
train_bowler_df, test_bowler_df = train_test_split(
    venue_grouped_bowler, test_size=0.2, random_state=42
)

# %%
X_train_batsman, y_train_batsman = train_batsman_df.iloc[:,:-1], train_batsman_df.iloc[:,-1:]

X_test_batsman, y_test_batsman = test_batsman_df.iloc[:,:-1], test_batsman_df.iloc[:,-1:]

X_train_bowler, y_train_bowler = train_bowler_df.iloc[:,:-1], train_bowler_df.iloc[:,-1:]

X_test_bowler, y_test_bowler = test_bowler_df.iloc[:,:-1], test_bowler_df.iloc[:,-1:]

# %%
# Print X_train_batsman column names
print("X_train Batsman Columns:")
print(X_train_batsman.columns)

# Print y_train_batsman column names
print("y_train Batsman Columns:")
print(y_train_batsman.columns)

# Print X_train_bowler column names
print("X_train Bowler Columns:")
print(X_train_bowler.columns)

# Print y_train_bowler column names
print("y_train Bowler Columns:")
print(y_train_bowler.columns)
# Out:
# X_train Batsman Columns:
# Index(['player', 'venue'], dtype='object')
# y_train Batsman Columns:
# Index(['d11'], dtype='object')
# X_train Bowler Columns:
# Index(['player', 'venue'], dtype='object')
# y_train Bowler Columns:
# Index(['d11'], dtype='object')

# %%
## Predicting for batsman
batsman_catboost_model.fit(X_train_batsman, y_train_batsman)
pred = batsman_catboost_model.predict(X_test_batsman)
r2 = r2_score(pred,y_test_batsman)
print('The r2 using gbr is:',r2)
# Out:
# The r2 using gbr is: -4.6730677515907635

# %%
## Predicting for bowler
bowler_gbr_model.fit(X_train_bowler, y_train_bowler)
pred = bowler_gbr_model.predict(X_test_bowler)
r2 = r2_score(pred,y_test_bowler)
print('The r2 using gbr is:',r2)
# Out:
# The r2 using gbr is: -31.554075936715144
